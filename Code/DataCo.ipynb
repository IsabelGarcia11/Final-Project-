# %% [markdown]
# Firstly we need to import below libraries

# %%
import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
Data=pd.read_csv('../DATA/DataCo/DataCoSupplyChainDataset.csv',encoding='latin-1')

# %%
Data.columns=[e.lower().replace(' ', '_').strip() for e in Data.columns]
Data.head(2)
# Out:
#        type  days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
#
#   customer_country customer_email customer_fname  customer_id customer_lname  \
# 0      Puerto Rico      XXXXXXXXX          Cally        20755       Holloway
# 1      Puerto Rico      XXXXXXXXX          Irene        19492           Luna
#
#   customer_password customer_segment customer_state           customer_street  \
# 0         XXXXXXXXX         Consumer             PR  5365 Noble Nectar Island
# 1         XXXXXXXXX         Consumer             PR          2679 Rustic Loop
#
#    customer_zipcode  department_id department_name   latitude  longitude  \
# 0             725.0              2         Fitness  18.251453 -66.037056
# 1             725.0              2         Fitness  18.279451 -66.037064
#
#          market order_city order_country  order_customer_id  \
# 0  Pacific Asia     Bekasi     Indonesia              20755
# 1  Pacific Asia    Bikaner         India              19492
#
#   order_date_(dateorders)  order_id  order_item_cardprod_id  \
# 0         1/31/2018 22:56     77202                    1360
# 1         1/13/2018 12:27     75939                    1360
#
#    order_item_discount  order_item_discount_rate  order_item_id  \
# 0            13.110000                      0.04         180517
# 1            16.389999                      0.05         179254
#
#    order_item_product_price  order_item_profit_ratio  order_item_quantity  \
# 0                    327.75                     0.29                    1
# 1                    327.75                    -0.80                    1
#
#     sales  order_item_total  order_profit_per_order    order_region  \
# 0  327.75        314.640015               91.250000  Southeast Asia
# 1  327.75        311.359985             -249.089996      South Asia
#
#        order_state order_status  order_zipcode  product_card_id  \
# 0  Java Occidental     COMPLETE            NaN             1360
# 1         Rajastán      PENDING            NaN             1360
#
#    product_category_id  product_description  \
# 0                   73                  NaN
# 1                   73                  NaN
#
#                                   product_image  product_name  product_price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
#
#    product_status shipping_date_(dateorders)   shipping_mode
# 0               0             2/3/2018 22:56  Standard Class
# 1               0            1/18/2018 12:27  Standard Class

# %%
def roundd(x):
    return round(x,2)

# %%
Data['benefit_per_order']=Data['benefit_per_order'].apply(roundd)
Data['sales_per_customer']=Data['sales_per_customer'].apply(roundd)
Data['order_item_discount']=Data['order_item_discount'].apply(roundd)
Data['order_item_discount_rate']=Data['order_item_discount_rate'].apply(roundd)
Data['order_item_product_price']=Data['order_item_product_price'].apply(roundd)
Data['order_item_profit_ratio']=Data['order_item_profit_ratio'].apply(roundd)
Data['sales']=Data['sales'].apply(roundd)
Data['order_item_total']=Data['order_item_total'].apply(roundd)
Data['order_profit_per_order']=Data['order_profit_per_order'].apply(roundd)
Data['product_price']=Data['product_price'].apply(roundd)

# %%
Data.shape
# Out:
# (180519, 53)

# %%
nan=Data.isnull().sum()
nan.sort_values(ascending=False)[:4]
# Out:
# product_description    180519
# order_zipcode          155679
# customer_lname              8
# customer_zipcode            3
# dtype: int64

# %%
Data[['customer_zipcode']]=Data[['customer_zipcode']].fillna(value=0)

# %%
Data=Data.astype({'customer_zipcode':'int32'})

# %%
Data=Data.drop(columns=['customer_email','customer_fname','customer_lname','customer_password','order_zipcode',
                       'product_description','product_image','product_status'])

# %%
column_names = [ 'type','customer_city','customer_country','customer_state','latitude', 'longitude','customer_street', 
 'customer_zipcode','customer_id','customer_segment','market', 'order_city','order_country', 'order_region','order_state',
 'order_customer_id','department_id','department_name','order_id','order_item_id','order_item_quantity','order_item_cardprod_id','order_item_discount',
 'order_item_discount_rate','order_item_product_price','order_item_profit_ratio','benefit_per_order','order_profit_per_order',
 'order_item_total','product_price','sales_per_customer','sales','category_id','category_name', 
 'product_card_id','product_category_id','product_name', 'order_status','order_date_(dateorders)',
 'shipping_date_(dateorders)','shipping_mode','days_for_shipping_(real)','days_for_shipment_(scheduled)','delivery_status',
 'late_delivery_risk']
df1 = Data.reindex(columns=column_names)

# %%
df1.head(2)
# Out:
#        type customer_city customer_country customer_state   latitude  \
# 0     DEBIT        Caguas      Puerto Rico             PR  18.251453
# 1  TRANSFER        Caguas      Puerto Rico             PR  18.279451
#
#    longitude           customer_street  customer_zipcode  customer_id  \
# 0 -66.037056  5365 Noble Nectar Island               725        20755
# 1 -66.037064          2679 Rustic Loop               725        19492
#
#   customer_segment        market order_city order_country    order_region  \
# 0         Consumer  Pacific Asia     Bekasi     Indonesia  Southeast Asia
# 1         Consumer  Pacific Asia    Bikaner         India      South Asia
#
#        order_state  order_customer_id  department_id department_name  \
# 0  Java Occidental              20755              2         Fitness
# 1         Rajastán              19492              2         Fitness
#
#    order_id  order_item_id  order_item_quantity  order_item_cardprod_id  \
# 0     77202         180517                    1                    1360
# 1     75939         179254                    1                    1360
#
#    order_item_discount  order_item_discount_rate  order_item_product_price  \
# 0                13.11                      0.04                    327.75
# 1                16.39                      0.05                    327.75
#
#    order_item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0                     0.29              91.25                   91.25
# 1                    -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  sales_per_customer   sales  category_id  \
# 0            314.64         327.75              314.64  327.75           73
# 1            311.36         327.75              311.36  327.75           73
#
#     category_name  product_card_id  product_category_id  product_name  \
# 0  Sporting Goods             1360                   73  Smart watch
# 1  Sporting Goods             1360                   73  Smart watch
#
#   order_status order_date_(dateorders) shipping_date_(dateorders)  \
# 0     COMPLETE         1/31/2018 22:56             2/3/2018 22:56
# 1      PENDING         1/13/2018 12:27            1/18/2018 12:27
#
#     shipping_mode  days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 0  Standard Class                         3                              4
# 1  Standard Class                         5                              4
#
#     delivery_status  late_delivery_risk
# 0  Advance shipping                   0
# 1     Late delivery                   1

# %%
# df.customer_city.unique() CA--California city condado de Kern

# %%
df1.loc[df1['customer_state'] == '91732']
# Out:
#         type customer_city customer_country customer_state   latitude  \
# 82511  DEBIT            CA          EE. UU.          91732  34.071892
#
#         longitude customer_street  customer_zipcode  customer_id  \
# 82511 -118.013886        El Monte                 0        14046
#
#       customer_segment  market order_city order_country     order_region  \
# 82511         Consumer  Europe  Sheffield   Reino Unido  Northern Europe
#
#       order_state  order_customer_id  department_id department_name  order_id  \
# 82511  Inglaterra              14046              4         Apparel     70493
#
#        order_item_id  order_item_quantity  order_item_cardprod_id  \
# 82511         173808                    1                    1350
#
#        order_item_discount  order_item_discount_rate  \
# 82511                57.14                      0.16
#
#        order_item_product_price  order_item_profit_ratio  benefit_per_order  \
# 82511                     357.1                      0.2              59.99
#
#        order_profit_per_order  order_item_total  product_price  \
# 82511                   59.99            299.96          357.1
#
#        sales_per_customer  sales  category_id        category_name  \
# 82511              299.96  357.1           63  Children's Clothing
#
#        product_card_id  product_category_id        product_name order_status  \
# 82511             1350                   63  Children's heaters     COMPLETE
#
#       order_date_(dateorders) shipping_date_(dateorders)   shipping_mode  \
# 82511         10/26/2017 0:29            10/30/2017 0:29  Standard Class
#
#        days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 82511                         4                              4
#
#         delivery_status  late_delivery_risk
# 82511  Shipping on time                   0

# %%
df1['customer_state']=[i.replace(i,'CA') if i=='91732' or i=='95758' else i for i in df1['customer_state']]

# %%
df1.rename(columns = {'type':'transaction_type','customer_city':'store_city','customer_country':'store_country',
                     'customer_state':'store_state','latitude':'latitude_store','longitude':'longitude_store',
                     'customer_street':'store_street','customer_zipcode':'store_zipcode','market':'customer_market',
                     'order_city':'customer_city','order_item_cardprod_id':'rfid_order_id',
                     'sales_per_customer':'total_sales_per_customer','product_card_id':'product_id',
                     'order_date_(dateorders)':'order_date','shipping_date_(dateorders)':'delivery_date',
    'days_for_shipping_(real)':'real_shipping_days','days_for_shipment_(scheduled)':'scheduled_shipping_days',
                    'order_region':'customer_region','order_item_discount':'item_discount',
                      'order_item_discount_rate':'item_discount_rate',
                    'order_item_id':'item_id','order_item_profit_ratio':'item_profit_ratio',
                    'order_item_quantity':'item_quantity',}, inplace = True)

# %%
df1.head(2)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
#
#   customer_segment customer_market customer_city order_country  \
# 0         Consumer    Pacific Asia        Bekasi     Indonesia
# 1         Consumer    Pacific Asia       Bikaner         India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status       order_date    delivery_date   shipping_mode  \
# 0     COMPLETE  1/31/2018 22:56   2/3/2018 22:56  Standard Class
# 1      PENDING  1/13/2018 12:27  1/18/2018 12:27  Standard Class
#
#    real_shipping_days  scheduled_shipping_days   delivery_status  \
# 0                   3                        4  Advance shipping
# 1                   5                        4     Late delivery
#
#    late_delivery_risk
# 0                   0
# 1                   1

# %%
df1.rename(columns = {'order_country':'customer_country'}, inplace = True)

# %%
df1.head(2)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
#
#   customer_segment customer_market customer_city customer_country  \
# 0         Consumer    Pacific Asia        Bekasi        Indonesia
# 1         Consumer    Pacific Asia       Bikaner            India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status       order_date    delivery_date   shipping_mode  \
# 0     COMPLETE  1/31/2018 22:56   2/3/2018 22:56  Standard Class
# 1      PENDING  1/13/2018 12:27  1/18/2018 12:27  Standard Class
#
#    real_shipping_days  scheduled_shipping_days   delivery_status  \
# 0                   3                        4  Advance shipping
# 1                   5                        4     Late delivery
#
#    late_delivery_risk
# 0                   0
# 1                   1

# %%
df1.late_delivery_risk.value_counts()
# Out:
# 1    98977
# 0    81542
# Name: late_delivery_risk, dtype: int64

# %%
df1['order_date']=pd.to_datetime(df1['order_date'])      #convertimos a formato datetime para sacar año y mes
df1['delivery_date']=pd.to_datetime(df1['delivery_date'])

# %%
df1['order_year'] = df1['order_date'].dt.year
df1['order_month'] = df1['order_date'].dt.month

# %%
df1.head(2)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
#
#   customer_segment customer_market customer_city customer_country  \
# 0         Consumer    Pacific Asia        Bekasi        Indonesia
# 1         Consumer    Pacific Asia       Bikaner            India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status          order_date       delivery_date   shipping_mode  \
# 0     COMPLETE 2018-01-31 22:56:00 2018-02-03 22:56:00  Standard Class
# 1      PENDING 2018-01-13 12:27:00 2018-01-18 12:27:00  Standard Class
#
#    real_shipping_days  scheduled_shipping_days   delivery_status  \
# 0                   3                        4  Advance shipping
# 1                   5                        4     Late delivery
#
#    late_delivery_risk  order_year  order_month
# 0                   0        2018            1
# 1                   1        2018            1

# %%
df=df1.copy()

# %%
df['order_date']=df['order_date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))
df['delivery_date']=df['delivery_date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
df.head(3)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
# 2             CASH   San Jose       EE. UU.          CA       37.292233
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
# 2      -121.881279      8510 Round Bear Gate          95125        19491
#
#   customer_segment customer_market customer_city customer_country  \
# 0         Consumer    Pacific Asia        Bekasi        Indonesia
# 1         Consumer    Pacific Asia       Bikaner            India
# 2         Consumer    Pacific Asia       Bikaner            India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
# 2      South Asia         Rajastán              19491              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
# 2         Fitness     75938   179253              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
# 2          18.03                0.06                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
# 2              -0.80            -247.78                 -247.78
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
# 2            309.72         327.75                    309.72  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
# 2           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status  order_date delivery_date   shipping_mode  real_shipping_days  \
# 0     COMPLETE  31/01/2018    03/02/2018  Standard Class                   3
# 1      PENDING  13/01/2018    18/01/2018  Standard Class                   5
# 2       CLOSED  13/01/2018    17/01/2018  Standard Class                   4
#
#    scheduled_shipping_days   delivery_status  late_delivery_risk  order_year  \
# 0                        4  Advance shipping                   0        2018
# 1                        4     Late delivery                   1        2018
# 2                        4  Shipping on time                   0        2018
#
#    order_month
# 0            1
# 1            1
# 2            1

# %%
#sum((df.order_item_total == df.total_sales_per_customer) == False)==0  #borramos la columna al ser igual que la otra

# %%
#sum((df.order_profit_per_order == df.benefit_per_order) == False)==0   #borramos la columna al ser igual que la otra

# %%
#sum((df.order_item_product_price == df.product_price) == False)==0     #borramos la columna al ser igual que la otra

# %%
df=df.drop(columns=['order_state','customer_market','order_item_total','order_profit_per_order',
                   'order_item_product_price','store_street','store_zipcode','rfid_order_id',
                   'department_id','category_id','product_category_id','order_customer_id','product_id'])

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount  item_discount_rate  item_profit_ratio  \
# 0              1          13.11                0.04               0.29
# 1              1          16.39                0.05              -0.80
# 2              1          18.03                0.06              -0.80
# 3              1          22.94                0.07               0.08
# 4              1          29.50                0.09               0.45
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
def country(x): 
    if x=='Japón':
        return 'Japan'
    elif x=='Corea del Sur':
        return 'South Korea'
    elif x=='Turquía':
        return 'Turkey'
    elif x=='Estados Unidos':
        return 'United States'
    elif x=='República Democrática del Congo':
        return 'DR Congo'
    elif x=='República del Congo':
        return 'DR Congo'
    elif x=='Marruecos':
        return 'Morocco'
    elif x=='Alemania':
        return 'Germany'
    elif x== 'Francia':
        return 'France'
    elif x=='Países Bajos':
        return 'Netherlands'
    elif x== 'Reino Unido':
        return 'United Kingdom'
    elif x=='Panamá' :
        return 'Panama'
    elif x=='República Dominicana':
        return 'Dominican Republic'
    elif x== 'Brasil':
        return 'Brazil'
    elif x=='México' :
        return 'Mexico'
    elif x== 'Perú':
        return 'Peru'
    elif x== 'Sudán':
        return 'Sudan'
    elif x== 'Costa de Marfil':
        return 'Ivory Coast'
    elif x== 'Libia':
        return 'Libya'
    elif x== 'Egipto':
        return 'Egypt'
    elif x== 'Italia':
        return 'Italy'
    elif x== 'España':
        return 'Spain'
    elif x== 'Suecia':
        return 'Sweden'
    elif x== 'Níger':
        return 'Niger'
    elif x== 'SudAfrica':
        return 'South Africa'
    elif x== 'Ruanda':
        return 'Rwanda'
    elif x== 'Nueva Zelanda':
        return 'New Zeland'
    elif x== 'Bangladés':
        return 'Bangladesh'
    elif x=='Trinidad y Tobago':
        return 'Trinidad and Tobago'
    elif x=='Tailandia':
        return 'Thailand'
    elif x=='Arabia Saudí':
        return 'Saudi Arabia'
    elif x=='Irán':
        return 'Iran'
    elif x=='Myanmar (Birmania)':
        return 'Myanmar'
    elif x=='Uzbekistán':
        return 'Uzbekistan'
    elif x=='Benín':
        return 'Benin'
    elif x=='Camerún':
        return 'Camerun'
    elif x=='Ucrania':
        return 'Ukraine'
    elif x=='Polonia':
        return 'Poland'
    elif x=='Rumania':
        return 'Romania'
    elif x=='Afganistán':
        return 'Afghanistan'
    elif x=='Pakistán':
        return 'Pakistan'
    elif x=='Malasia':
        return 'Malaysia'
    elif x=='Finlandia':
        return 'Finland'
    elif x=='Rusia':
        return 'Russia'
    elif x=='Irlanda':
        return 'Ireland'
    elif x=='Noruega':
        return 'Norway'
    elif x=='Eslovaquia':
        return 'Slovakia'
    elif x=='Bélgica':
        return 'Belgium'
    elif x=='Etiopía':
        return 'Ethiopia'
    elif x=='Lituania':
        return 'Lithuania'
    elif x=='Kirguistán':
        return 'Kyrgyzstan'
    elif x=='Lesoto':
        return 'Lesotho'
    elif x=='Emiratos Árabes Unidos':
        return 'United Arab Emirates'
    elif x=='Suiza':
        return 'Switzerland'
    elif x=='Hungría':
        return 'Hungary'
    elif x=='Dinamarca':
        return 'Denmark'
    elif x=='Haití':
        return 'Haiti'
    elif x=='Bielorrusia':
        return 'Belarus'
    elif x=='Croacia':
        return 'Croatia'
    elif x=='Baréin':
        return 'Bahrain'
    elif x=='Zimbabue':
        return 'Zimbabwe'
    elif x=='República Checa':
        return 'Czech Republic'
    elif x=='Tayikistán':
        return 'Tajikistan'
    elif x=='Papúa Nueva Guinea':
        return 'Papua New Guinea'
    elif x=='Azerbaiyán':
        return 'Azerbaijan'
    elif x=='Turkmenistán':
        return 'Turkmenistan'
    elif x=='Jordania':
        return 'Jordan'
    elif x=='Martinica':
        return 'Martinique'
    elif x=='Moldavia':
        return 'Moldova'
    elif x=='Bosnia y Herzegovina':
        return 'Bosnia and Herzegovina'
    elif x=='Omán':
        return 'Oman'
    elif x=='Túnez':
        return 'Tunisia'
    elif x=='Sierra Leona':
        return 'Sierra Leone'
    elif x=='Yibuti':
        return 'Djibouti'
    elif x=='Gabón':
        return 'Gabon'
    elif x=='Sudán del Sur':
        return 'Sudan'
    elif x=='Luxemburgo':
        return 'Luxembourg'
    elif x=='Mauritania':
        return 'Mauritania'
    elif x=='Grecia':
        return 'Greece'
    elif x=='Suazilandia':
        return 'Swaziland'
    elif x=='Guayana Francesa':
        return 'French Polynesia'
    elif x=='República Centroafricana':
        return 'Central African Republic'
    elif x=='Taiwán':
        return 'Taiwan'
    elif x=='Líbano':
        return 'Libano'
    elif x=='Chipre':
        return  'Cyprus'
    elif x=='Surinam':
        return 'Suriname'
    elif x=='Belice':
        return 'Belize'
    elif x=='República de Gambia':
        return 'Gambia'
    elif x=='Sáhara Occidental':
        return 'Western Sahara'
    elif x=='Botsuana':
        return 'Botswana'
    elif x=='Guinea Ecuatorial':
        return 'Guinea'
    elif x=='Bután':
        return 'Butan'
    elif x=='Filipinas':
        return 'Philippines'
    else:
        return x

# %%
df['customer_country']=df['customer_country'].apply(country)

# %%
df['item_discount_rate']=(df['item_discount_rate']*100).round(2).astype(str) +'%'
df['item_profit_ratio']=(df['item_profit_ratio']*100).round(2).astype(str) +'%'

# %%
df.shape
# Out:
# (180519, 34)

# %%
df['customer_country'] = df['customer_country'].astype(str)

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount item_discount_rate item_profit_ratio  \
# 0              1          13.11               4.0%             29.0%
# 1              1          16.39               5.0%            -80.0%
# 2              1          18.03               6.0%            -80.0%
# 3              1          22.94               7.0%              8.0%
# 4              1          29.50               9.0%             45.0%
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
df.store_city.value_counts()
# Out:
# Caguas         66770
# Chicago         3885
# Los Angeles     3417
# Brooklyn        3412
# New York        1816
#                ...
# Bartlett          25
# Malden            22
# Ponce             22
# Freehold          13
# CA                 3
# Name: store_city, Length: 563, dtype: int64

# %%
df.customer_city.value_counts()
# Out:
# Santo Domingo    2211
# New York City    2202
# Los Angeles      1845
# Tegucigalpa      1783
# Managua          1682
#                  ...
# Libourne            1
# Bergerac            1
# Juliaca             1
# Takasaki            1
# Pernik              1
# Name: customer_city, Length: 3597, dtype: int64

# %%
pd.set_option('display.max_rows', None)
#df.customer_country.value_counts()  pendiente de traducir

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount item_discount_rate item_profit_ratio  \
# 0              1          13.11               4.0%             29.0%
# 1              1          16.39               5.0%            -80.0%
# 2              1          18.03               6.0%            -80.0%
# 3              1          22.94               7.0%              8.0%
# 4              1          29.50               9.0%             45.0%
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
#apertura nueva tienda, precio producto/pais, tipos de cliente/mkt , ventas epocas del año (pedidos cancelados), xq late delivery

# %%
def usa(x):
    if x=='EE.UU':
        return 'United States'
    else:
        return x

# %%
df['store_country']=df['store_country'].apply(usa)

# %%
df.to_csv('Final_3.csv', index=False)

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount item_discount_rate item_profit_ratio  \
# 0              1          13.11               4.0%             29.0%
# 1              1          16.39               5.0%            -80.0%
# 2              1          18.03               6.0%            -80.0%
# 3              1          22.94               7.0%              8.0%
# 4              1          29.50               9.0%             45.0%
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
df.loc[df['customer_city'] == 'Tegucigalpa'].loc[df['store_city']=='Caguas']
# Out:
#        transaction_type store_city store_country store_state  latitude_store  \
# 83              PAYMENT     Caguas   Puerto Rico          PR       18.296848
# 504             PAYMENT     Caguas   Puerto Rico          PR       18.200869
# 640            TRANSFER     Caguas   Puerto Rico          PR       18.231676
# 642            TRANSFER     Caguas   Puerto Rico          PR       18.241051
# 648            TRANSFER     Caguas   Puerto Rico          PR       18.283012
# 657            TRANSFER     Caguas   Puerto Rico          PR       18.359394
# 674            TRANSFER     Caguas   Puerto Rico          PR       18.201494
# 1283            PAYMENT     Caguas   Puerto Rico          PR       18.296848
# 2854           TRANSFER     Caguas   Puerto Rico          PR       18.227800
# 3044            PAYMENT     Caguas   Puerto Rico          PR       18.297235
# 3164            PAYMENT     Caguas   Puerto Rico          PR       18.295229
# 3166            PAYMENT     Caguas   Puerto Rico          PR       18.228422
# 3279              DEBIT     Caguas   Puerto Rico          PR       18.213873
# 3281              DEBIT     Caguas   Puerto Rico          PR       18.212212
# 3354              DEBIT     Caguas   Puerto Rico          PR       18.287666
# 3372              DEBIT     Caguas   Puerto Rico          PR       18.287666
# 3458              DEBIT     Caguas   Puerto Rico          PR       18.287666
# 3962               CASH     Caguas   Puerto Rico          PR       18.249622
# 3965               CASH     Caguas   Puerto Rico          PR       18.292662
# 5675               CASH     Caguas   Puerto Rico          PR       18.274244
# 6463            PAYMENT     Caguas   Puerto Rico          PR       18.296520
# 6469            PAYMENT     Caguas   Puerto Rico          PR       18.260122
# 6472            PAYMENT     Caguas   Puerto Rico          PR       18.297235
# 6614            PAYMENT     Caguas   Puerto Rico          PR       18.296520
# 6615            PAYMENT     Caguas   Puerto Rico          PR       18.296520
# 6616            PAYMENT     Caguas   Puerto Rico          PR       18.296520
# 6619            PAYMENT     Caguas   Puerto Rico          PR       18.228422
# 6797            PAYMENT     Caguas   Puerto Rico          PR       18.297235
# 6798            PAYMENT     Caguas   Puerto Rico          PR       18.283232
# 7211              DEBIT     Caguas   Puerto Rico          PR       18.212212
# 7247              DEBIT     Caguas   Puerto Rico          PR       18.287666
# 7424              DEBIT     Caguas   Puerto Rico          PR       18.213873
# 7428              DEBIT     Caguas   Puerto Rico          PR       18.212212
# 7468              DEBIT     Caguas   Puerto Rico          PR       18.218407
# 7691               CASH     Caguas   Puerto Rico          PR       18.225628
# 7702               CASH     Caguas   Puerto Rico          PR       18.263474
# 7705               CASH     Caguas   Puerto Rico          PR       18.225628
# 7835               CASH     Caguas   Puerto Rico          PR       18.225628
# 7868               CASH     Caguas   Puerto Rico          PR       18.263474
# 7910               CASH     Caguas   Puerto Rico          PR       18.263474
# 8120               CASH     Caguas   Puerto Rico          PR       18.274244
# 8141               CASH     Caguas   Puerto Rico          PR       18.276094
# 8169               CASH     Caguas   Puerto Rico          PR       18.206663
# 8214               CASH     Caguas   Puerto Rico          PR       18.206663
# 8242               CASH     Caguas   Puerto Rico          PR       18.253716
# 10821          TRANSFER     Caguas   Puerto Rico          PR       18.239782
# 10824          TRANSFER     Caguas   Puerto Rico          PR       18.227800
# 10829          TRANSFER     Caguas   Puerto Rico          PR       18.213285
# 10840          TRANSFER     Caguas   Puerto Rico          PR       18.239782
# 10845          TRANSFER     Caguas   Puerto Rico          PR       18.213285
# 10849          TRANSFER     Caguas   Puerto Rico          PR       18.227800
# 10974          TRANSFER     Caguas   Puerto Rico          PR       18.239782
# 11025          TRANSFER     Caguas   Puerto Rico          PR       18.239782
# 11130          TRANSFER     Caguas   Puerto Rico          PR       18.216404
# 11131          TRANSFER     Caguas   Puerto Rico          PR       18.239782
# 11177          TRANSFER     Caguas   Puerto Rico          PR       18.245159
# 11236          TRANSFER     Caguas   Puerto Rico          PR       18.245159
# 11367          TRANSFER     Caguas   Puerto Rico          PR       18.230701
# 11368          TRANSFER     Caguas   Puerto Rico          PR       18.230701
# 11644          TRANSFER     Caguas   Puerto Rico          PR       18.230701
# 12026             DEBIT     Caguas   Puerto Rico          PR       18.212212
# 12244             DEBIT     Caguas   Puerto Rico          PR       18.209742
# 12257             DEBIT     Caguas   Puerto Rico          PR       18.229071
# 20058             DEBIT     Caguas   Puerto Rico          PR       18.257973
# 20060             DEBIT     Caguas   Puerto Rico          PR       18.274948
# 20069             DEBIT     Caguas   Puerto Rico          PR       18.276247
# 20073             DEBIT     Caguas   Puerto Rico          PR       18.276247
# 20100             DEBIT     Caguas   Puerto Rico          PR       18.257973
# 20166             DEBIT     Caguas   Puerto Rico          PR       18.200657
# 20198             DEBIT     Caguas   Puerto Rico          PR       18.238010
# 20244             DEBIT     Caguas   Puerto Rico          PR       18.278393
# 20259             DEBIT     Caguas   Puerto Rico          PR       18.278393
# 20260             DEBIT     Caguas   Puerto Rico          PR       18.292690
# 20345             DEBIT     Caguas   Puerto Rico          PR       18.282988
# 20429             DEBIT     Caguas   Puerto Rico          PR       18.292690
# 20441             DEBIT     Caguas   Puerto Rico          PR       18.247583
# 20584             DEBIT     Caguas   Puerto Rico          PR       18.242916
# 20593             DEBIT     Caguas   Puerto Rico          PR       18.257973
# 20603             DEBIT     Caguas   Puerto Rico          PR       18.227581
# 20614             DEBIT     Caguas   Puerto Rico          PR       18.227581
# 20739             DEBIT     Caguas   Puerto Rico          PR       18.204926
# 20824             DEBIT     Caguas   Puerto Rico          PR       18.204926
# 22252             DEBIT     Caguas   Puerto Rico          PR       18.295366
# 22284             DEBIT     Caguas   Puerto Rico          PR       18.229019
# 22299             DEBIT     Caguas   Puerto Rico          PR       18.229019
# 22304             DEBIT     Caguas   Puerto Rico          PR       18.272804
# 22306             DEBIT     Caguas   Puerto Rico          PR       18.272804
# 22318             DEBIT     Caguas   Puerto Rico          PR       18.276247
# 22319             DEBIT     Caguas   Puerto Rico          PR       18.247583
# 22323             DEBIT     Caguas   Puerto Rico          PR       18.276247
# 22325             DEBIT     Caguas   Puerto Rico          PR       18.225758
# 22370             DEBIT     Caguas   Puerto Rico          PR       18.262299
# 25946              CASH     Caguas   Puerto Rico          PR       18.206663
# 26044              CASH     Caguas   Puerto Rico          PR       18.253716
# 26155              CASH     Caguas   Puerto Rico          PR       18.276094
# 26158              CASH     Caguas   Puerto Rico          PR       18.276094
# 26161              CASH     Caguas   Puerto Rico          PR       18.253716
# 26179              CASH     Caguas   Puerto Rico          PR       18.206663
# 26521             DEBIT     Caguas   Puerto Rico          PR       18.219744
# 26542             DEBIT     Caguas   Puerto Rico          PR       18.219744
# 26577             DEBIT     Caguas   Puerto Rico          PR       18.219744
# 26584             DEBIT     Caguas   Puerto Rico          PR       18.282757
# 26846             DEBIT     Caguas   Puerto Rico          PR       18.282757
# 26961             DEBIT     Caguas   Puerto Rico          PR       18.219744
# 30206          TRANSFER     Caguas   Puerto Rico          PR       18.276686
# 30214          TRANSFER     Caguas   Puerto Rico          PR       18.276686
# 30217          TRANSFER     Caguas   Puerto Rico          PR       18.276686
# 30228          TRANSFER     Caguas   Puerto Rico          PR       18.262260
# 30269          TRANSFER     Caguas   Puerto Rico          PR       18.262260
# 30278          TRANSFER     Caguas   Puerto Rico          PR       18.236322
# 30282          TRANSFER     Caguas   Puerto Rico          PR       18.226175
# 30287          TRANSFER     Caguas   Puerto Rico          PR       18.275187
# 30293          TRANSFER     Caguas   Puerto Rico          PR       18.226175
# 30318          TRANSFER     Caguas   Puerto Rico          PR       18.262260
# 30322          TRANSFER     Caguas   Puerto Rico          PR       18.283005
# 30326          TRANSFER     Caguas   Puerto Rico          PR       18.297504
# 30349          TRANSFER     Caguas   Puerto Rico          PR       18.297504
# 30413          TRANSFER     Caguas   Puerto Rico          PR       18.238462
# 30414          TRANSFER     Caguas   Puerto Rico          PR       18.238462
# 30422          TRANSFER     Caguas   Puerto Rico          PR       18.212196
# 30775          TRANSFER     Caguas   Puerto Rico          PR       18.283005
# 30808          TRANSFER     Caguas   Puerto Rico          PR       18.212196
# 30940          TRANSFER     Caguas   Puerto Rico          PR       18.236322
# 30944          TRANSFER     Caguas   Puerto Rico          PR       18.226175
# 30972          TRANSFER     Caguas   Puerto Rico          PR       18.247560
# 30987          TRANSFER     Caguas   Puerto Rico          PR       18.297504
# 30996          TRANSFER     Caguas   Puerto Rico          PR       18.238462
# 31121          TRANSFER     Caguas   Puerto Rico          PR       18.276686
# 31126          TRANSFER     Caguas   Puerto Rico          PR       18.262260
# 31141          TRANSFER     Caguas   Puerto Rico          PR       18.283005
# 31156          TRANSFER     Caguas   Puerto Rico          PR       18.247560
# 31332          TRANSFER     Caguas   Puerto Rico          PR       18.262260
# 31340          TRANSFER     Caguas   Puerto Rico          PR       18.247560
# 31859             DEBIT     Caguas   Puerto Rico          PR       18.290607
# 32117             DEBIT     Caguas   Puerto Rico          PR       18.238087
# 32563          TRANSFER     Caguas   Puerto Rico          PR       18.297504
# 32889           PAYMENT     Caguas   Puerto Rico          PR       18.296520
# 32894              CASH     Caguas   Puerto Rico          PR       18.229248
# 39138             DEBIT     Caguas   Puerto Rico          PR       18.298512
# 39344             DEBIT     Caguas   Puerto Rico          PR       18.294132
# 39409             DEBIT     Caguas   Puerto Rico          PR       18.285782
# 39411             DEBIT     Caguas   Puerto Rico          PR       18.294132
# 39435             DEBIT     Caguas   Puerto Rico          PR       18.294132
# 39439             DEBIT     Caguas   Puerto Rico          PR       18.285782
# 39481             DEBIT     Caguas   Puerto Rico          PR       18.251713
# 39800             DEBIT     Caguas   Puerto Rico          PR       18.251713
# 40069             DEBIT     Caguas   Puerto Rico          PR       18.251713
# 40160             DEBIT     Caguas   Puerto Rico          PR       18.294132
# 40906             DEBIT     Caguas   Puerto Rico          PR       18.209398
# 40913             DEBIT     Caguas   Puerto Rico          PR       18.268909
# 40975             DEBIT     Caguas   Puerto Rico          PR       18.262344
# 41079             DEBIT     Caguas   Puerto Rico          PR       18.228443
# 41190             DEBIT     Caguas   Puerto Rico          PR       18.262344
# 41244             DEBIT     Caguas   Puerto Rico          PR       18.228443
# 41249             DEBIT     Caguas   Puerto Rico          PR       18.230309
# 41264             DEBIT     Caguas   Puerto Rico          PR       18.241045
# 41291             DEBIT     Caguas   Puerto Rico          PR       18.231295
# 51045             DEBIT     Caguas   Puerto Rico          PR       18.242916
# 51056          TRANSFER     Caguas   Puerto Rico          PR       18.231676
# 51058          TRANSFER     Caguas   Puerto Rico          PR       18.224089
# 51166           PAYMENT     Caguas   Puerto Rico          PR       18.250458
# 51369              CASH     Caguas   Puerto Rico          PR       18.294218
# 51412             DEBIT     Caguas   Puerto Rico          PR       18.246670
# 51664             DEBIT     Caguas   Puerto Rico          PR       18.227581
# 51732           PAYMENT     Caguas   Puerto Rico          PR       18.293045
# 54491             DEBIT     Caguas   Puerto Rico          PR       18.257973
# 54782           PAYMENT     Caguas   Puerto Rico          PR       18.243986
# 54836              CASH     Caguas   Puerto Rico          PR       18.261656
# 54888           PAYMENT     Caguas   Puerto Rico          PR       18.297235
# 54889           PAYMENT     Caguas   Puerto Rico          PR       18.297235
# 55036          TRANSFER     Caguas   Puerto Rico          PR       18.205336
# 55066           PAYMENT     Caguas   Puerto Rico          PR       18.235708
# 55148             DEBIT     Caguas   Puerto Rico          PR       18.210588
# 55149             DEBIT     Caguas   Puerto Rico          PR       18.210588
# 55152             DEBIT     Caguas   Puerto Rico          PR       18.242477
# 55153             DEBIT     Caguas   Puerto Rico          PR       18.201923
# 55154          TRANSFER     Caguas   Puerto Rico          PR       18.297504
# 55155          TRANSFER     Caguas   Puerto Rico          PR       18.267229
# 55189          TRANSFER     Caguas   Puerto Rico          PR       18.216824
# 55200             DEBIT     Caguas   Puerto Rico          PR       18.241045
# 55203           PAYMENT     Caguas   Puerto Rico          PR       18.224871
# 55204           PAYMENT     Caguas   Puerto Rico          PR       18.250458
# 55205           PAYMENT     Caguas   Puerto Rico          PR       18.250458
# 55206          TRANSFER     Caguas   Puerto Rico          PR       18.232922
# 55272          TRANSFER     Caguas   Puerto Rico          PR       18.245159
# 55273              CASH     Caguas   Puerto Rico          PR       18.292662
# 55293           PAYMENT     Caguas   Puerto Rico          PR       18.204300
# 55398              CASH     Caguas   Puerto Rico          PR       18.285355
# 55501          TRANSFER     Caguas   Puerto Rico          PR       18.253971
# 55677             DEBIT     Caguas   Puerto Rico          PR       18.212593
# 55764           PAYMENT     Caguas   Puerto Rico          PR       18.200869
# 55801              CASH     Caguas   Puerto Rico          PR       18.276094
# 55920          TRANSFER     Caguas   Puerto Rico          PR       18.214415
# 55949          TRANSFER     Caguas   Puerto Rico          PR       18.229542
# 56093          TRANSFER     Caguas   Puerto Rico          PR       18.230701
# 56180          TRANSFER     Caguas   Puerto Rico          PR       18.216404
# 56443             DEBIT     Caguas   Puerto Rico          PR       18.262344
# 56527             DEBIT     Caguas   Puerto Rico          PR       18.247583
# 56561             DEBIT     Caguas   Puerto Rico          PR       18.272804
# 56630             DEBIT     Caguas   Puerto Rico          PR       18.262299
# 56683             DEBIT     Caguas   Puerto Rico          PR       18.242916
# 56691             DEBIT     Caguas   Puerto Rico          PR       18.200657
# 56696             DEBIT     Caguas   Puerto Rico          PR       18.223564
# 57248             DEBIT     Caguas   Puerto Rico          PR       18.276201
# 57270             DEBIT     Caguas   Puerto Rico          PR       18.229019
# 57316             DEBIT     Caguas   Puerto Rico          PR       18.247583
# 57320             DEBIT     Caguas   Puerto Rico          PR       18.227581
# 57346             DEBIT     Caguas   Puerto Rico          PR       18.223564
# 57382             DEBIT     Caguas   Puerto Rico          PR       18.229019
# 57386             DEBIT     Caguas   Puerto Rico          PR       18.226261
# 57395             DEBIT     Caguas   Puerto Rico          PR       18.295366
# 58005             DEBIT     Caguas   Puerto Rico          PR       18.238010
# 58077             DEBIT     Caguas   Puerto Rico          PR       18.242916
# 58085             DEBIT     Caguas   Puerto Rico          PR       18.200657
# 58107             DEBIT     Caguas   Puerto Rico          PR       18.274948
# 58114             DEBIT     Caguas   Puerto Rico          PR       18.292690
# 58132             DEBIT     Caguas   Puerto Rico          PR       18.276201
# 58160             DEBIT     Caguas   Puerto Rico          PR       18.262299
# 58183             DEBIT     Caguas   Puerto Rico          PR       18.218590
# 58193             DEBIT     Caguas   Puerto Rico          PR       18.204926
# 58196             DEBIT     Caguas   Puerto Rico          PR       18.204926
# 58637           PAYMENT     Caguas   Puerto Rico          PR       18.278162
# 58644           PAYMENT     Caguas   Puerto Rico          PR       18.208208
# 58645           PAYMENT     Caguas   Puerto Rico          PR       18.278162
# 58656           PAYMENT     Caguas   Puerto Rico          PR       18.214321
# 58711           PAYMENT     Caguas   Puerto Rico          PR       18.264174
# 58715           PAYMENT     Caguas   Puerto Rico          PR       18.264174
# 58936           PAYMENT     Caguas   Puerto Rico          PR       18.273840
# 58945           PAYMENT     Caguas   Puerto Rico          PR       18.273840
# 59135           PAYMENT     Caguas   Puerto Rico          PR       18.208208
# 59244           PAYMENT     Caguas   Puerto Rico          PR       18.264174
# 59387           PAYMENT     Caguas   Puerto Rico          PR       18.218101
# 61548             DEBIT     Caguas   Puerto Rico          PR       18.266064
# 61685          TRANSFER     Caguas   Puerto Rico          PR       18.260183
# 61783           PAYMENT     Caguas   Puerto Rico          PR       18.217751
# 61876              CASH     Caguas   Puerto Rico          PR       18.206663
# 61916             DEBIT     Caguas   Puerto Rico          PR       18.292690
# 61944          TRANSFER     Caguas   Puerto Rico          PR       18.236322
# 62216             DEBIT     Caguas   Puerto Rico          PR       18.238087
# 62259             DEBIT     Caguas   Puerto Rico          PR       18.287666
# 62298          TRANSFER     Caguas   Puerto Rico          PR       18.288946
# 62299           PAYMENT     Caguas   Puerto Rico          PR       18.296848
# 62300           PAYMENT     Caguas   Puerto Rico          PR       18.228422
# 67056             DEBIT     Caguas   Puerto Rico          PR       18.212593
# 67080             DEBIT     Caguas   Puerto Rico          PR       18.212593
# 67083             DEBIT     Caguas   Puerto Rico          PR       18.212593
# 67436             DEBIT     Caguas   Puerto Rico          PR       18.254105
# 67437             DEBIT     Caguas   Puerto Rico          PR       18.254105
# 67463             DEBIT     Caguas   Puerto Rico          PR       18.262344
# 67529             DEBIT     Caguas   Puerto Rico          PR       18.218775
# 67901             DEBIT     Caguas   Puerto Rico          PR       18.230309
# 67914             DEBIT     Caguas   Puerto Rico          PR       18.214003
# 68270             DEBIT     Caguas   Puerto Rico          PR       18.254105
# 68364             DEBIT     Caguas   Puerto Rico          PR       18.241045
# 68365             DEBIT     Caguas   Puerto Rico          PR       18.218775
# 68367             DEBIT     Caguas   Puerto Rico          PR       18.214003
# 69358           PAYMENT     Caguas   Puerto Rico          PR       18.257444
# 69362           PAYMENT     Caguas   Puerto Rico          PR       18.281931
# 69366           PAYMENT     Caguas   Puerto Rico          PR       18.281931
# 69381           PAYMENT     Caguas   Puerto Rico          PR       18.257444
# 69425           PAYMENT     Caguas   Puerto Rico          PR       18.257444
# 69436           PAYMENT     Caguas   Puerto Rico          PR       18.219330
# 72589          TRANSFER     Caguas   Puerto Rico          PR       18.253515
# 72628              CASH     Caguas   Puerto Rico          PR       18.225758
# 75617              CASH     Caguas   Puerto Rico          PR       18.253325
# 75618              CASH     Caguas   Puerto Rico          PR       18.253325
# 75619              CASH     Caguas   Puerto Rico          PR       18.253325
# 75621          TRANSFER     Caguas   Puerto Rico          PR       18.283005
# 75708              CASH     Caguas   Puerto Rico          PR       18.249884
# 75709              CASH     Caguas   Puerto Rico          PR       18.249884
# 75804             DEBIT     Caguas   Puerto Rico          PR       18.298512
# 75944             DEBIT     Caguas   Puerto Rico          PR       18.262299
# 76016           PAYMENT     Caguas   Puerto Rico          PR       18.248764
# 76017          TRANSFER     Caguas   Puerto Rico          PR       18.241051
# 76103             DEBIT     Caguas   Puerto Rico          PR       18.234850
# 76106          TRANSFER     Caguas   Puerto Rico          PR       18.245291
# 76173           PAYMENT     Caguas   Puerto Rico          PR       18.263489
# 76225          TRANSFER     Caguas   Puerto Rico          PR       18.221539
# 76331          TRANSFER     Caguas   Puerto Rico          PR       18.203033
# 76374             DEBIT     Caguas   Puerto Rico          PR       18.213873
# 76384              CASH     Caguas   Puerto Rico          PR       18.205427
# 76520          TRANSFER     Caguas   Puerto Rico          PR       18.207466
# 76521          TRANSFER     Caguas   Puerto Rico          PR       18.207466
# 76570           PAYMENT     Caguas   Puerto Rico          PR       18.244116
# 76749             DEBIT     Caguas   Puerto Rico          PR       18.228443
# 76750             DEBIT     Caguas   Puerto Rico          PR       18.228443
# 76998           PAYMENT     Caguas   Puerto Rico          PR       18.278162
# 90089           PAYMENT     Caguas   Puerto Rico          PR       18.281931
# 90247           PAYMENT     Caguas   Puerto Rico          PR       18.281931
# 90337           PAYMENT     Caguas   Puerto Rico          PR       18.257444
# 90346           PAYMENT     Caguas   Puerto Rico          PR       18.257444
# 90837           PAYMENT     Caguas   Puerto Rico          PR       18.263489
# 90847           PAYMENT     Caguas   Puerto Rico          PR       18.243986
# 90862           PAYMENT     Caguas   Puerto Rico          PR       18.248690
# 90908           PAYMENT     Caguas   Puerto Rico          PR       18.248690
# 90964           PAYMENT     Caguas   Puerto Rico          PR       18.250458
# 90991           PAYMENT     Caguas   Puerto Rico          PR       18.270887
# 91544           PAYMENT     Caguas   Puerto Rico          PR       18.227833
# 91568           PAYMENT     Caguas   Puerto Rico          PR       18.263489
# 91572           PAYMENT     Caguas   Puerto Rico          PR       18.263489
# 91582           PAYMENT     Caguas   Puerto Rico          PR       18.248690
# 91757           PAYMENT     Caguas   Puerto Rico          PR       18.243986
# 91777           PAYMENT     Caguas   Puerto Rico          PR       18.243986
# 91817           PAYMENT     Caguas   Puerto Rico          PR       18.270887
# 91818           PAYMENT     Caguas   Puerto Rico          PR       18.263489
# 92045           PAYMENT     Caguas   Puerto Rico          PR       18.227833
# 92069           PAYMENT     Caguas   Puerto Rico          PR       18.243986
# 92070           PAYMENT     Caguas   Puerto Rico          PR       18.270887
# 92280           PAYMENT     Caguas   Puerto Rico          PR       18.248690
# 92289           PAYMENT     Caguas   Puerto Rico          PR       18.270887
# 92317           PAYMENT     Caguas   Puerto Rico          PR       18.227833
# 92767          TRANSFER     Caguas   Puerto Rico          PR       18.253515
# 104568             CASH     Caguas   Puerto Rico          PR       18.249884
# 105388         TRANSFER     Caguas   Puerto Rico          PR       18.298174
# 105416          PAYMENT     Caguas   Puerto Rico          PR       18.218101
# 105417          PAYMENT     Caguas   Puerto Rico          PR       18.218101
# 105436            DEBIT     Caguas   Puerto Rico          PR       18.231295
# 105604             CASH     Caguas   Puerto Rico          PR       18.203083
# 105605          PAYMENT     Caguas   Puerto Rico          PR       18.227577
# 105794         TRANSFER     Caguas   Puerto Rico          PR       18.290270
# 105915         TRANSFER     Caguas   Puerto Rico          PR       18.255098
# 105974            DEBIT     Caguas   Puerto Rico          PR       18.219744
# 106129          PAYMENT     Caguas   Puerto Rico          PR       18.293045
# 106137            DEBIT     Caguas   Puerto Rico          PR       18.201923
# 106139         TRANSFER     Caguas   Puerto Rico          PR       18.267229
# 106191          PAYMENT     Caguas   Puerto Rico          PR       18.224871
# 106192          PAYMENT     Caguas   Puerto Rico          PR       18.250458
# 106275         TRANSFER     Caguas   Puerto Rico          PR       18.245159
# 106363            DEBIT     Caguas   Puerto Rico          PR       18.282988
# 106365            DEBIT     Caguas   Puerto Rico          PR       18.238010
# 106451             CASH     Caguas   Puerto Rico          PR       18.228558
# 106490            DEBIT     Caguas   Puerto Rico          PR       18.229542
# 106686         TRANSFER     Caguas   Puerto Rico          PR       18.243113
# 106893          PAYMENT     Caguas   Puerto Rico          PR       18.200869
# 106894          PAYMENT     Caguas   Puerto Rico          PR       18.200869
# 107126             CASH     Caguas   Puerto Rico          PR       18.249622
# 107127             CASH     Caguas   Puerto Rico          PR       18.249622
# 107233          PAYMENT     Caguas   Puerto Rico          PR       18.219492
# 107244         TRANSFER     Caguas   Puerto Rico          PR       18.227577
# 107414         TRANSFER     Caguas   Puerto Rico          PR       18.216404
# 107473            DEBIT     Caguas   Puerto Rico          PR       18.227709
# 107474            DEBIT     Caguas   Puerto Rico          PR       18.227709
# 107485          PAYMENT     Caguas   Puerto Rico          PR       18.293959
# 110644            DEBIT     Caguas   Puerto Rico          PR       18.276201
# 110811            DEBIT     Caguas   Puerto Rico          PR       18.207993
# 111000            DEBIT     Caguas   Puerto Rico          PR       18.254633
# 111006            DEBIT     Caguas   Puerto Rico          PR       18.246670
# 111007            DEBIT     Caguas   Puerto Rico          PR       18.246670
# 113332            DEBIT     Caguas   Puerto Rico          PR       18.272804
# 113333            DEBIT     Caguas   Puerto Rico          PR       18.272804
# 113403            DEBIT     Caguas   Puerto Rico          PR       18.298512
# 113466         TRANSFER     Caguas   Puerto Rico          PR       18.238462
# 113483            DEBIT     Caguas   Puerto Rico          PR       18.359106
# 113484            DEBIT     Caguas   Puerto Rico          PR       18.359106
# 113737         TRANSFER     Caguas   Puerto Rico          PR       18.225719
# 113788         TRANSFER     Caguas   Puerto Rico          PR       18.245291
# 113789         TRANSFER     Caguas   Puerto Rico          PR       18.245291
# 113931         TRANSFER     Caguas   Puerto Rico          PR       18.221539
# 114127            DEBIT     Caguas   Puerto Rico          PR       18.251713
# 114445            DEBIT     Caguas   Puerto Rico          PR       18.286873
# 114580            DEBIT     Caguas   Puerto Rico          PR       18.228443
# 114603          PAYMENT     Caguas   Puerto Rico          PR       18.281931
# 114742         TRANSFER     Caguas   Puerto Rico          PR       18.206017
# 114772         TRANSFER     Caguas   Puerto Rico          PR       18.209063
# 114904          PAYMENT     Caguas   Puerto Rico          PR       18.278162
# 122163         TRANSFER     Caguas   Puerto Rico          PR       18.296520
# 122164         TRANSFER     Caguas   Puerto Rico          PR       18.296520
# 122167         TRANSFER     Caguas   Puerto Rico          PR       18.296520
# 122181         TRANSFER     Caguas   Puerto Rico          PR       18.351297
# 122251         TRANSFER     Caguas   Puerto Rico          PR       18.296520
# 122286         TRANSFER     Caguas   Puerto Rico          PR       18.221539
# 122309         TRANSFER     Caguas   Puerto Rico          PR       18.221539
# 122338         TRANSFER     Caguas   Puerto Rico          PR       18.296520
# 122341         TRANSFER     Caguas   Puerto Rico          PR       18.351297
# 122523         TRANSFER     Caguas   Puerto Rico          PR       18.255098
# 122530         TRANSFER     Caguas   Puerto Rico          PR       18.255098
# 122535         TRANSFER     Caguas   Puerto Rico          PR       18.255098
# 122540         TRANSFER     Caguas   Puerto Rico          PR       18.222237
# 122548         TRANSFER     Caguas   Puerto Rico          PR       18.222237
# 122572         TRANSFER     Caguas   Puerto Rico          PR       18.255098
# 122596         TRANSFER     Caguas   Puerto Rico          PR       18.205336
# 122627         TRANSFER     Caguas   Puerto Rico          PR       18.205336
# 122938         TRANSFER     Caguas   Puerto Rico          PR       18.288363
# 122953         TRANSFER     Caguas   Puerto Rico          PR       18.205336
# 122955         TRANSFER     Caguas   Puerto Rico          PR       18.227573
# 123052         TRANSFER     Caguas   Puerto Rico          PR       18.222237
# 123155         TRANSFER     Caguas   Puerto Rico          PR       18.222237
# 123750         TRANSFER     Caguas   Puerto Rico          PR       18.267229
# 123761         TRANSFER     Caguas   Puerto Rico          PR       18.246557
# 123770         TRANSFER     Caguas   Puerto Rico          PR       18.225719
# 123803         TRANSFER     Caguas   Puerto Rico          PR       18.246557
# 123831         TRANSFER     Caguas   Puerto Rico          PR       18.267229
# 123840         TRANSFER     Caguas   Puerto Rico          PR       18.225719
# 123842         TRANSFER     Caguas   Puerto Rico          PR       18.232922
# 123848         TRANSFER     Caguas   Puerto Rico          PR       18.258162
# 123856         TRANSFER     Caguas   Puerto Rico          PR       18.258162
# 123859         TRANSFER     Caguas   Puerto Rico          PR       18.227577
# 123862         TRANSFER     Caguas   Puerto Rico          PR       18.227577
# 123867         TRANSFER     Caguas   Puerto Rico          PR       18.249622
# 123904         TRANSFER     Caguas   Puerto Rico          PR       18.246475
# 123913         TRANSFER     Caguas   Puerto Rico          PR       18.297083
# 123930         TRANSFER     Caguas   Puerto Rico          PR       18.214415
# 123937         TRANSFER     Caguas   Puerto Rico          PR       18.214415
# 123944         TRANSFER     Caguas   Puerto Rico          PR       18.297083
# 123981         TRANSFER     Caguas   Puerto Rico          PR       18.246475
# 123994         TRANSFER     Caguas   Puerto Rico          PR       18.270124
# 124013         TRANSFER     Caguas   Puerto Rico          PR       18.275555
# 124016         TRANSFER     Caguas   Puerto Rico          PR       18.275555
# 124019         TRANSFER     Caguas   Puerto Rico          PR       18.230701
# 124032         TRANSFER     Caguas   Puerto Rico          PR       18.275555
# 124607         TRANSFER     Caguas   Puerto Rico          PR       18.227577
# 124616         TRANSFER     Caguas   Puerto Rico          PR       18.245291
# 124623         TRANSFER     Caguas   Puerto Rico          PR       18.245291
# 124629         TRANSFER     Caguas   Puerto Rico          PR       18.246557
# 124631         TRANSFER     Caguas   Puerto Rico          PR       18.249622
# 124638         TRANSFER     Caguas   Puerto Rico          PR       18.225719
# 124639         TRANSFER     Caguas   Puerto Rico          PR       18.232922
# 124665         TRANSFER     Caguas   Puerto Rico          PR       18.253971
# 124674         TRANSFER     Caguas   Puerto Rico          PR       18.253971
# 125328          PAYMENT     Caguas   Puerto Rico          PR       18.245399
# 125342          PAYMENT     Caguas   Puerto Rico          PR       18.359100
# 125345          PAYMENT     Caguas   Puerto Rico          PR       18.359100
# 125356          PAYMENT     Caguas   Puerto Rico          PR       18.293045
# 125394          PAYMENT     Caguas   Puerto Rico          PR       18.293045
# 125408          PAYMENT     Caguas   Puerto Rico          PR       18.293045
# 125448          PAYMENT     Caguas   Puerto Rico          PR       18.359100
# 125480          PAYMENT     Caguas   Puerto Rico          PR       18.260183
# 125791          PAYMENT     Caguas   Puerto Rico          PR       18.260183
# 126041          PAYMENT     Caguas   Puerto Rico          PR       18.220152
# 126163          PAYMENT     Caguas   Puerto Rico          PR       18.359100
# 126186          PAYMENT     Caguas   Puerto Rico          PR       18.359100
# 126901          PAYMENT     Caguas   Puerto Rico          PR       18.219492
# 126923          PAYMENT     Caguas   Puerto Rico          PR       18.219492
# 126954          PAYMENT     Caguas   Puerto Rico          PR       18.227577
# 126974          PAYMENT     Caguas   Puerto Rico          PR       18.204300
# 126984          PAYMENT     Caguas   Puerto Rico          PR       18.212868
# 127033          PAYMENT     Caguas   Puerto Rico          PR       18.221001
# 127045          PAYMENT     Caguas   Puerto Rico          PR       18.217751
# 127075          PAYMENT     Caguas   Puerto Rico          PR       18.235708
# 127097          PAYMENT     Caguas   Puerto Rico          PR       18.217751
# 127125          PAYMENT     Caguas   Puerto Rico          PR       18.293959
# 127136          PAYMENT     Caguas   Puerto Rico          PR       18.216558
# 127194          PAYMENT     Caguas   Puerto Rico          PR       18.291374
# 127203          PAYMENT     Caguas   Puerto Rico          PR       18.279999
# 127206          PAYMENT     Caguas   Puerto Rico          PR       18.293959
# 127239          PAYMENT     Caguas   Puerto Rico          PR       18.224871
# 127241          PAYMENT     Caguas   Puerto Rico          PR       18.204300
# 127257          PAYMENT     Caguas   Puerto Rico          PR       18.204300
# 127272          PAYMENT     Caguas   Puerto Rico          PR       18.255533
# 127286          PAYMENT     Caguas   Puerto Rico          PR       18.248764
# 127314          PAYMENT     Caguas   Puerto Rico          PR       18.279999
# 127328          PAYMENT     Caguas   Puerto Rico          PR       18.212868
# 127355          PAYMENT     Caguas   Puerto Rico          PR       18.268513
# 127356          PAYMENT     Caguas   Puerto Rico          PR       18.221001
# 127398          PAYMENT     Caguas   Puerto Rico          PR       18.216558
# 137179             CASH     Caguas   Puerto Rico          PR       18.255356
# 137180             CASH     Caguas   Puerto Rico          PR       18.255356
# 137245          PAYMENT     Caguas   Puerto Rico          PR       18.260122
# 137253            DEBIT     Caguas   Puerto Rico          PR       18.257973
# 137312          PAYMENT     Caguas   Puerto Rico          PR       18.216558
# 137313         TRANSFER     Caguas   Puerto Rico          PR       18.298174
# 137314         TRANSFER     Caguas   Puerto Rico          PR       18.298174
# 137346         TRANSFER     Caguas   Puerto Rico          PR       18.249622
# 137350            DEBIT     Caguas   Puerto Rico          PR       18.231295
# 137520             CASH     Caguas   Puerto Rico          PR       18.203083
# 137659         TRANSFER     Caguas   Puerto Rico          PR       18.261984
# 137660         TRANSFER     Caguas   Puerto Rico          PR       18.261984
# 137726             CASH     Caguas   Puerto Rico          PR       18.273474
# 137798            DEBIT     Caguas   Puerto Rico          PR       18.218407
# 137799            DEBIT     Caguas   Puerto Rico          PR       18.218407
# 137972            DEBIT     Caguas   Puerto Rico          PR       18.242477
# 138013            DEBIT     Caguas   Puerto Rico          PR       18.241045
# 138015          PAYMENT     Caguas   Puerto Rico          PR       18.224871
# 138016            DEBIT     Caguas   Puerto Rico          PR       18.214003
# 138084         TRANSFER     Caguas   Puerto Rico          PR       18.245159
# 138194             CASH     Caguas   Puerto Rico          PR       18.285355
# 138195         TRANSFER     Caguas   Puerto Rico          PR       18.201494
# 138264            DEBIT     Caguas   Puerto Rico          PR       18.278393
# 138265            DEBIT     Caguas   Puerto Rico          PR       18.295366
# 138333         TRANSFER     Caguas   Puerto Rico          PR       18.253971
# 138439         TRANSFER     Caguas   Puerto Rico          PR       18.291517
# 138505          PAYMENT     Caguas   Puerto Rico          PR       18.212868
# 138521            DEBIT     Caguas   Puerto Rico          PR       18.212593
# 138766         TRANSFER     Caguas   Puerto Rico          PR       18.294939
# 138767         TRANSFER     Caguas   Puerto Rico          PR       18.294939
# 138768            DEBIT     Caguas   Puerto Rico          PR       18.200657
# 138788             CASH     Caguas   Puerto Rico          PR       18.249622
# 138805         TRANSFER     Caguas   Puerto Rico          PR       18.229542
# 138843            DEBIT     Caguas   Puerto Rico          PR       18.229019
# 138910         TRANSFER     Caguas   Puerto Rico          PR       18.227577
# 138952         TRANSFER     Caguas   Puerto Rico          PR       18.230701
# 139046         TRANSFER     Caguas   Puerto Rico          PR       18.216404
# 139134         TRANSFER     Caguas   Puerto Rico          PR       18.226175
# 139241         TRANSFER     Caguas   Puerto Rico          PR       18.247560
# 139332            DEBIT     Caguas   Puerto Rico          PR       18.276201
# 139333            DEBIT     Caguas   Puerto Rico          PR       18.276201
# 139371         TRANSFER     Caguas   Puerto Rico          PR       18.249622
# 139381         TRANSFER     Caguas   Puerto Rico          PR       18.258162
# 139414         TRANSFER     Caguas   Puerto Rico          PR       18.298174
# 139421         TRANSFER     Caguas   Puerto Rico          PR       18.246475
# 139428         TRANSFER     Caguas   Puerto Rico          PR       18.359095
# 139429         TRANSFER     Caguas   Puerto Rico          PR       18.359095
# 139675         TRANSFER     Caguas   Puerto Rico          PR       18.232922
# 139691         TRANSFER     Caguas   Puerto Rico          PR       18.275555
# 139692         TRANSFER     Caguas   Puerto Rico          PR       18.298174
# 139729         TRANSFER     Caguas   Puerto Rico          PR       18.297083
# 139976         TRANSFER     Caguas   Puerto Rico          PR       18.232922
# 139982         TRANSFER     Caguas   Puerto Rico          PR       18.258162
# 139989         TRANSFER     Caguas   Puerto Rico          PR       18.249622
# 140025         TRANSFER     Caguas   Puerto Rico          PR       18.214415
# 140689             CASH     Caguas   Puerto Rico          PR       18.261656
# 141434            DEBIT     Caguas   Puerto Rico          PR       18.201923
# 141512            DEBIT     Caguas   Puerto Rico          PR       18.201923
# 141518            DEBIT     Caguas   Puerto Rico          PR       18.201923
# 141783            DEBIT     Caguas   Puerto Rico          PR       18.287630
# 142037            DEBIT     Caguas   Puerto Rico          PR       18.223684
# 142063            DEBIT     Caguas   Puerto Rico          PR       18.290607
# 145277            DEBIT     Caguas   Puerto Rico          PR       18.207993
# 145327          PAYMENT     Caguas   Puerto Rico          PR       18.208208
# 145399            DEBIT     Caguas   Puerto Rico          PR       18.223564
# 145415            DEBIT     Caguas   Puerto Rico          PR       18.254633
# 148034            DEBIT     Caguas   Puerto Rico          PR       18.223684
# 148041            DEBIT     Caguas   Puerto Rico          PR       18.242477
# 148123            DEBIT     Caguas   Puerto Rico          PR       18.297991
# 148216            DEBIT     Caguas   Puerto Rico          PR       18.290607
# 148273            DEBIT     Caguas   Puerto Rico          PR       18.290607
# 148789            DEBIT     Caguas   Puerto Rico          PR       18.271656
# 148813            DEBIT     Caguas   Puerto Rico          PR       18.210588
# 148956            DEBIT     Caguas   Puerto Rico          PR       18.271656
# 149563            DEBIT     Caguas   Puerto Rico          PR       18.210588
# 149598            DEBIT     Caguas   Puerto Rico          PR       18.260141
# 149612            DEBIT     Caguas   Puerto Rico          PR       18.266064
# 149892            DEBIT     Caguas   Puerto Rico          PR       18.266064
# 150561          PAYMENT     Caguas   Puerto Rico          PR       18.267296
# 150566          PAYMENT     Caguas   Puerto Rico          PR       18.244116
# 154310          PAYMENT     Caguas   Puerto Rico          PR       18.267683
# 154332          PAYMENT     Caguas   Puerto Rico          PR       18.279999
# 154414          PAYMENT     Caguas   Puerto Rico          PR       18.227577
# 154425          PAYMENT     Caguas   Puerto Rico          PR       18.204300
# 154778          PAYMENT     Caguas   Puerto Rico          PR       18.219492
# 154798          PAYMENT     Caguas   Puerto Rico          PR       18.235708
# 154802          PAYMENT     Caguas   Puerto Rico          PR       18.221001
# 154803          PAYMENT     Caguas   Puerto Rico          PR       18.216558
# 154810          PAYMENT     Caguas   Puerto Rico          PR       18.267321
# 154851          PAYMENT     Caguas   Puerto Rico          PR       18.216558
# 154852          PAYMENT     Caguas   Puerto Rico          PR       18.235708
# 155217          PAYMENT     Caguas   Puerto Rico          PR       18.219492
# 155297          PAYMENT     Caguas   Puerto Rico          PR       18.255533
# 155335          PAYMENT     Caguas   Puerto Rico          PR       18.212868
# 155675          PAYMENT     Caguas   Puerto Rico          PR       18.204300
# 155704          PAYMENT     Caguas   Puerto Rico          PR       18.221001
# 155719          PAYMENT     Caguas   Puerto Rico          PR       18.293959
# 155784          PAYMENT     Caguas   Puerto Rico          PR       18.235708
# 155789          PAYMENT     Caguas   Puerto Rico          PR       18.279999
# 156224         TRANSFER     Caguas   Puerto Rico          PR       18.211309
# 156900         TRANSFER     Caguas   Puerto Rico          PR       18.211309
# 157045         TRANSFER     Caguas   Puerto Rico          PR       18.211309
# 157778         TRANSFER     Caguas   Puerto Rico          PR       18.288946
# 157783         TRANSFER     Caguas   Puerto Rico          PR       18.296423
# 157818         TRANSFER     Caguas   Puerto Rico          PR       18.288946
# 157830         TRANSFER     Caguas   Puerto Rico          PR       18.296423
# 157831         TRANSFER     Caguas   Puerto Rico          PR       18.278997
# 158415         TRANSFER     Caguas   Puerto Rico          PR       18.278997
# 158572         TRANSFER     Caguas   Puerto Rico          PR       18.288946
# 159521         TRANSFER     Caguas   Puerto Rico          PR       18.224089
# 159556         TRANSFER     Caguas   Puerto Rico          PR       18.207466
# 159566         TRANSFER     Caguas   Puerto Rico          PR       18.216824
# 159574         TRANSFER     Caguas   Puerto Rico          PR       18.216824
# 159598         TRANSFER     Caguas   Puerto Rico          PR       18.294939
# 159607         TRANSFER     Caguas   Puerto Rico          PR       18.243113
# 159639         TRANSFER     Caguas   Puerto Rico          PR       18.291517
# 159648         TRANSFER     Caguas   Puerto Rico          PR       18.291517
# 159720         TRANSFER     Caguas   Puerto Rico          PR       18.229542
# 159721         TRANSFER     Caguas   Puerto Rico          PR       18.252680
# 159792         TRANSFER     Caguas   Puerto Rico          PR       18.025375
# 159797         TRANSFER     Caguas   Puerto Rico          PR       18.025375
# 159856         TRANSFER     Caguas   Puerto Rico          PR       18.264801
# 159913         TRANSFER     Caguas   Puerto Rico          PR       18.201494
# 159923         TRANSFER     Caguas   Puerto Rico          PR       18.201494
# 159933         TRANSFER     Caguas   Puerto Rico          PR       18.264801
# 159940         TRANSFER     Caguas   Puerto Rico          PR       18.359394
# 159953         TRANSFER     Caguas   Puerto Rico          PR       18.295542
# 159955         TRANSFER     Caguas   Puerto Rico          PR       18.295542
# 159997         TRANSFER     Caguas   Puerto Rico          PR       18.201494
# 160001         TRANSFER     Caguas   Puerto Rico          PR       18.283012
# 160011         TRANSFER     Caguas   Puerto Rico          PR       18.283012
# 160035         TRANSFER     Caguas   Puerto Rico          PR       18.241051
# 160060         TRANSFER     Caguas   Puerto Rico          PR       18.283012
# 161167         TRANSFER     Caguas   Puerto Rico          PR       18.207466
# 161176         TRANSFER     Caguas   Puerto Rico          PR       18.261984
# 161199         TRANSFER     Caguas   Puerto Rico          PR       18.291517
# 161225         TRANSFER     Caguas   Puerto Rico          PR       18.025375
# 161234         TRANSFER     Caguas   Puerto Rico          PR       18.203033
# 161262         TRANSFER     Caguas   Puerto Rico          PR       18.260183
# 161270         TRANSFER     Caguas   Puerto Rico          PR       18.359394
# 161279         TRANSFER     Caguas   Puerto Rico          PR       18.264801
# 161305         TRANSFER     Caguas   Puerto Rico          PR       18.231676
# 161309         TRANSFER     Caguas   Puerto Rico          PR       18.359394
# 161669         TRANSFER     Caguas   Puerto Rico          PR       18.207466
# ...
# 122309                   0        2015            2
# 122338                   0        2015            4
# 122341                   1        2017            3
# 122523                   1        2017            5
# 122530                   1        2017            5
# 122535                   1        2017            5
# 122540                   1        2017            3
# 122548                   1        2017            3
# 122572                   1        2017            5
# 122596                   1        2017            5
# 122627                   1        2017            5
# 122938                   1        2017            3
# 122953                   1        2017            5
# 122955                   1        2015            1
# 123052                   1        2017            3
# 123155                   1        2017            3
# 123750                   0        2017            4
# 123761                   0        2015            3
# 123770                   0        2015            3
# 123803                   0        2015            3
# 123831                   0        2017            4
# 123840                   0        2015            3
# 123842                   0        2017            4
# 123848                   0        2015            1
# 123856                   0        2015            1
# 123859                   1        2017            3
# 123862                   1        2017            3
# 123867                   1        2017            6
# 123904                   0        2015            2
# 123913                   1        2015            3
# 123930                   0        2017            3
# 123937                   0        2017            3
# 123944                   1        2015            3
# 123981                   0        2015            2
# 123994                   1        2015            3
# 124013                   1        2015            5
# 124016                   1        2015            5
# 124019                   0        2017            2
# 124032                   1        2015            5
# 124607                   1        2017            3
# 124616                   1        2015            3
# 124623                   1        2015            3
# 124629                   0        2015            3
# 124631                   1        2017            6
# 124638                   0        2015            3
# 124639                   0        2017            4
# 124665                   0        2017            4
# 124674                   0        2017            4
# 125328                   1        2017            4
# 125342                   0        2015            4
# 125345                   0        2015            4
# 125356                   1        2017            4
# 125394                   1        2017            4
# 125408                   1        2017            4
# 125448                   0        2015            4
# 125480                   1        2015            5
# 125791                   1        2015            5
# 126041                   0        2015            3
# 126163                   0        2015            4
# 126186                   0        2015            4
# 126901                   0        2017            3
# 126923                   0        2017            3
# 126954                   0        2017            5
# 126974                   0        2017            4
# 126984                   0        2017            3
# 127033                   1        2015            2
# 127045                   0        2015            5
# 127075                   0        2017            5
# 127097                   0        2015            5
# 127125                   0        2017            2
# 127136                   0        2017            6
# 127194                   0        2015            3
# 127203                   0        2015            5
# 127206                   0        2017            2
# 127239                   0        2017            4
# 127241                   0        2017            4
# 127257                   0        2017            4
# 127272                   0        2015            4
# 127286                   1        2015            3
# 127314                   0        2015            5
# 127328                   0        2017            3
# 127355                   0        2015            3
# 127356                   1        2015            2
# 127398                   0        2017            6
# 137179                   1        2017            6
# 137180                   1        2017            6
# 137245                   1        2017            6
# 137253                   0        2017            6
# 137312                   0        2017            6
# 137313                   1        2017            6
# 137314                   1        2017            6
# 137346                   1        2017            6
# 137350                   0        2017            6
# 137520                   1        2017            5
# 137659                   1        2017            5
# 137660                   1        2017            5
# 137726                   0        2017            5
# 137798                   0        2017            5
# 137799                   0        2017            5
# 137972                   1        2017            4
# 138013                   1        2017            4
# 138015                   0        2017            4
# 138016                   0        2017            4
# 138084                   0        2017            4
# 138194                   0        2017            4
# 138195                   0        2017            4
# 138264                   0        2017            4
# 138265                   0        2017            4
# 138333                   0        2017            4
# 138439                   1        2017            3
# 138505                   0        2017            3
# 138521                   0        2017            3
# 138766                   0        2017            3
# 138767                   0        2017            3
# 138768                   0        2017            3
# 138788                   1        2017            3
# 138805                   0        2017            3
# 138843                   0        2017            3
# 138910                   1        2017            3
# 138952                   0        2017            2
# 139046                   1        2017            2
# 139134                   0        2017            2
# 139241                   0        2017            2
# 139332                   1        2017            2
# 139333                   1        2017            2
# 139371                   1        2017            6
# 139381                   0        2015            1
# 139414                   1        2017            6
# 139421                   0        2015            2
# 139428                   0        2015            5
# 139429                   0        2015            5
# 139675                   0        2017            4
# 139691                   1        2015            5
# 139692                   1        2017            6
# 139729                   1        2015            3
# 139976                   0        2017            4
# 139982                   0        2015            1
# 139989                   1        2017            6
# 140025                   0        2017            3
# 140689                   0        2017            5
# 141434                   1        2017            4
# 141512                   1        2017            4
# 141518                   1        2017            4
# 141783                   0        2015            3
# 142037                   1        2017            5
# 142063                   1        2015            2
# 145277                   1        2017            1
# 145327                   1        2017            1
# 145399                   0        2017            1
# 145415                   1        2017            1
# 148034                   1        2017            5
# 148041                   1        2017            4
# 148123                   1        2017            1
# 148216                   1        2015            2
# 148273                   1        2015            2
# 148789                   1        2015            1
# 148813                   0        2017            4
# 148956                   1        2015            1
# 149563                   0        2017            4
# 149598                   1        2015            5
# 149612                   0        2015            5
# 149892                   0        2015            5
# 150561                   1        2015            4
# 150566                   1        2015            1
# 154310                   0        2017            5
# 154332                   0        2015            5
# 154414                   0        2017            5
# 154425                   0        2017            4
# 154778                   0        2017            3
# 154798                   0        2017            5
# 154802                   1        2015            2
# 154803                   0        2017            6
# 154810                   1        2017            6
# 154851                   0        2017            6
# 154852                   0        2017            5
# 155217                   0        2017            3
# 155297                   0        2015            4
# 155335                   0        2017            3
# 155675                   0        2015            1
# 155704                   1        2015            2
# 155719                   0        2017            2
# 155784                   0        2017            5
# 155789                   0        2015            5
# 156224                   1        2017            4
# 156900                   1        2017            4
# 157045                   1        2017            4
# 157778                   1        2015            4
# 157783                   1        2017            5
# 157818                   1        2015            4
# 157830                   1        2017            5
# 157831                   0        2015            4
# 158415                   0        2015            4
# 158572                   1        2015            4
# 159521                   0        2015            3
# 159556                   0        2015            2
# 159566                   1        2017            4
# 159574                   1        2017            4
# 159598                   0        2017            3
# 159607                   1        2017            3
# 159639                   1        2017            3
# 159648                   1        2017            3
# 159720                   0        2017            3
# 159721                   1        2017            1
# 159792                   0        2017            3
# 159797                   0        2017            3
# 159856                   1        2017            4
# 159913                   0        2017            4
# 159923                   0        2017            4
# 159933                   1        2017            4
# 159940                   1        2015            5
# 159953                   0        2017            4
# 159955                   0        2017            4
# 159997                   0        2017            4
# 160001                   1        2015            3
# 160011                   1        2015            3
# 160035                   0        2015            3
# 160060                   1        2015            3
# 161167                   0        2015            2
# 161176                   1        2017            5
# 161199                   1        2017            3
# 161225                   0        2017            3
# 161234                   0        2015            2
# 161262                   0        2015            5
# 161270                   1        2015            5
# 161279                   1        2017            4
# 161305                   1        2015            3
# 161309                   1        2015            5
# 161669                   0        2015            2
# 161685                   1        2017            5
# 161687                   1        2017            1
# 161708                   0        2017            3
# 161725                   0        2017            3
# 161729                   1        2017            3
# 161735                   0        2015            3
# 162181                   1        2017            3
# 162207                   0        2015            4
# 162270                   1        2015            3
# 162273                   1        2017            4
# 162306                   1        2015            5
# 172382                   1        2015            4
# 172389                   1        2017            6
# 172397                   1        2017            3
# 172520                   1        2015            4
# 172529                   1        2017            3
# 172534                   1        2017            6
# 172536                   1        2017            6
# 172614                   1        2017            3
# 173696                   0        2015            3
# 173722                   1        2015            2
# 173736                   0        2017            4
# 173795                   0        2017            5
# 173796                   1        2017            1
# 173808                   1        2017            2
# 173901                   1        2015            2
# 173908                   0        2017            5
# 173924                   1        2015            3
# 174331                   1        2015            3
# 174333                   1        2017            1
# 174557                   0        2015            3
# 174571                   1        2015            4
# 174585                   0        2017            5
# 174729                   1        2017            1
# 174749                   0        2015            2
# 174953                   1        2015            2
# 174959                   0        2017            4
# 174980                   1        2017            1
# 174995                   0        2017            2
# 175343                   1        2017            1
# 175377                   1        2015            3
# 175390                   1        2015            5
# 175495                   1        2017            1
# 175498                   1        2017            1
# 175555                   1        2015            4
# 175923                   1        2015            5
# 176122                   1        2015            3
# 176133                   1        2015            5
# 176166                   1        2015            4
# 176168                   1        2015            4
# 176370                   1        2015            4
# 176519                   1        2015            5
# 176549                   1        2015            5
# 178000                   1        2015            5
# 178036                   1        2015            5
# 178071                   1        2015            5
# 178151                   0        2015            5
# 178479                   0        2015            5
# 178556                   1        2015            4
# 178846                   1        2015            4
# 178892                   1        2015            4
# 178897                   1        2015            4
# 178899                   1        2015            4
# 178949                   1        2015            4
# 179183                   1        2015            4
# 179604                   1        2017            3
# 179619                   0        2015            4
# 179627                   0        2017            3

# %%
df.shape
# Out:
# (180519, 34)

# %% [markdown]
# DATASET 2

# %%
df2=pd.read_csv('../DATA/DataCo/tokenized_access_logs.csv')

# %%
df2.columns=[e.lower().replace(' ', '_').strip() for e in df2.columns]
df2.head(2)
# Out:
#                                    product             category  \
# 0  adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1    The North Face Women's Recon Backpack   hunting & shooting
#
#             date month  hour department            ip  \
# 0  9/1/2017 6:00   Sep     6   fitness   37.97.182.65
# 1  9/1/2017 6:00   Sep     6  fan shop   206.56.112.1
#
#                                                  url
# 0  /department/fitness/category/baseball%20&%20so...
# 1  /department/fan%20shop/category/hunting%20&%20...

# %%
df2.shape
# Out:
# (469977, 8)

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2['year'] = df2['date'].dt.year
df2['month_'] = df2['date'].dt.month

# %%
df2=df2.drop(columns=['month','hour','url'])

# %%
df2.head(2)
# Out:
#                                    product             category  \
# 0  adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1    The North Face Women's Recon Backpack   hunting & shooting
#
#                  date department            ip  year  month_
# 0 2017-09-01 06:00:00   fitness   37.97.182.65  2017       9
# 1 2017-09-01 06:00:00  fan shop   206.56.112.1  2017       9

# %%
Datas=df2.copy()

# %%
Datas['date']=Datas['date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
Datas.head()
# Out:
#                                       product             category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#          date department              ip  year  month_
# 0  01/09/2017   fitness     37.97.182.65  2017       9
# 1  01/09/2017  fan shop     206.56.112.1  2017       9
# 2  01/09/2017   apparel    215.143.180.0  2017       9
# 3  01/09/2017  footwear     206.56.112.1  2017       9
# 4  01/09/2017  fan shop   136.108.56.242  2017       9

# %%
Datas.year.value_counts()
# Out:
# 2017    386396
# 2018     83581
# Name: year, dtype: int64

# %%
Datas.to_csv('Token2.csv', index=False)
