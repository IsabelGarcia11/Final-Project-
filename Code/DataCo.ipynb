# %% [markdown]
# https://rstudio-pubs-static.s3.amazonaws.com/706595_c99afdec3b1541ddadf7e1703ebeae82.html

# %% [markdown]
# https://www.kaggle.com/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis?select=DescriptionDataCoSupplyChain.csv

# %% [markdown]
# https://es.fuelo.net/fuel/type/gasoline?lang=en  #gasolina españa precio diario

# %% [markdown]
# Firstly we need to import below libraries

# %%
import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
Data=pd.read_csv('../DATA/DataCo/DataCoSupplyChainDataset.csv',encoding='latin-1')

# %%
Data.columns=[e.lower().replace(' ', '_').strip() for e in Data.columns]
Data.head(2)
# Out:
#        type  days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
#
#   customer_country customer_email customer_fname  customer_id customer_lname  \
# 0      Puerto Rico      XXXXXXXXX          Cally        20755       Holloway
# 1      Puerto Rico      XXXXXXXXX          Irene        19492           Luna
#
#   customer_password customer_segment customer_state           customer_street  \
# 0         XXXXXXXXX         Consumer             PR  5365 Noble Nectar Island
# 1         XXXXXXXXX         Consumer             PR          2679 Rustic Loop
#
#    customer_zipcode  department_id department_name   latitude  longitude  \
# 0             725.0              2         Fitness  18.251453 -66.037056
# 1             725.0              2         Fitness  18.279451 -66.037064
#
#          market order_city order_country  order_customer_id  \
# 0  Pacific Asia     Bekasi     Indonesia              20755
# 1  Pacific Asia    Bikaner         India              19492
#
#   order_date_(dateorders)  order_id  order_item_cardprod_id  \
# 0         1/31/2018 22:56     77202                    1360
# 1         1/13/2018 12:27     75939                    1360
#
#    order_item_discount  order_item_discount_rate  order_item_id  \
# 0            13.110000                      0.04         180517
# 1            16.389999                      0.05         179254
#
#    order_item_product_price  order_item_profit_ratio  order_item_quantity  \
# 0                    327.75                     0.29                    1
# 1                    327.75                    -0.80                    1
#
#     sales  order_item_total  order_profit_per_order    order_region  \
# 0  327.75        314.640015               91.250000  Southeast Asia
# 1  327.75        311.359985             -249.089996      South Asia
#
#        order_state order_status  order_zipcode  product_card_id  \
# 0  Java Occidental     COMPLETE            NaN             1360
# 1         Rajastán      PENDING            NaN             1360
#
#    product_category_id  product_description  \
# 0                   73                  NaN
# 1                   73                  NaN
#
#                                   product_image  product_name  product_price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
#
#    product_status shipping_date_(dateorders)   shipping_mode
# 0               0             2/3/2018 22:56  Standard Class
# 1               0            1/18/2018 12:27  Standard Class

# %%
def roundd(x):
    return round(x,2)

# %%
Data['benefit_per_order']=Data['benefit_per_order'].apply(roundd)
Data['sales_per_customer']=Data['sales_per_customer'].apply(roundd)
Data['order_item_discount']=Data['order_item_discount'].apply(roundd)
Data['order_item_discount_rate']=Data['order_item_discount_rate'].apply(roundd)
Data['order_item_product_price']=Data['order_item_product_price'].apply(roundd)
Data['order_item_profit_ratio']=Data['order_item_profit_ratio'].apply(roundd)
Data['sales']=Data['sales'].apply(roundd)
Data['order_item_total']=Data['order_item_total'].apply(roundd)
Data['order_profit_per_order']=Data['order_profit_per_order'].apply(roundd)
Data['product_price']=Data['product_price'].apply(roundd)

# %%
Data.shape
# Out:
# (180519, 53)

# %%
nan=Data.isnull().sum()
nan.sort_values(ascending=False)[:4]
# Out:
# product_description    180519
# order_zipcode          155679
# customer_lname              8
# customer_zipcode            3
# dtype: int64

# %%
Data[['customer_zipcode']]=Data[['customer_zipcode']].fillna(value=0)

# %%
Data=Data.astype({'customer_zipcode':'int32'})

# %%
Data=Data.drop(columns=['customer_email','customer_fname','customer_lname','customer_password','order_zipcode',
                       'product_description','product_image','product_status'])

# %% [markdown]
# - **Type**: tipo de pago
# - **Days_ship_real**: días reales que ha tardado el envío
# - **Days_ship_sche**: días teóricos de envío
# - **Sales_per_customer**: Ventas totales por cliente realizadas por cliente
# - **Late_delivery_risk**: envío llega tarde (1),no está tarde (0).
# - **Customer_country**: : City where the customer made the purchase (Customer_state)--lugar de donde viene el pedido
# - **Customer_segment**: Types of Customers: Consumer , Corporate , Home Office
# - **Latitude**: Latitude corresponding to location of store (donde está la tienda que tiene el pedido)
# - **Market**: Market to where the order is delivered : Africa , Europe , LATAM , Pacific Asia , USCA
# - **Order Country**: Destination country of the order
# - **Order date (DateOrders)**: Date on which the order is made
# - **Order Customer Id**: Customer order code
# - **order_id**: Order code
# - **Order Item Cardprod Id**: Product code generated through the RFID reader
# - **Order Item Discount**:Order item discount value
# - **Order_item_discount_rate**: Order item discount percentage
# - **Order Item Id**: Order item code
# - **Order Item Product Price**: Price of products without discount
# - **Order Item Profit Ratio**: Order Item Profit Ratio
# - **Sales**: Value in sales
# - **Order Item Total**: Total amount per order
# - **Order Profit Per Order**: Order Profit Per Order
# - **Order Region** : Region of the world where the order is delivered : Southeast Asia ,South Asia ,Oceania ,Eastern ...
# - **Product Card Id**: Product code
# - **Product Price**: Product Price
# - **Product Status**: Status of the product stock :If it is 1 not available , 0 the product is available
# - **Shipping date (DateOrders)**: Exact date and time of shipment
#
# - **Days for shipping (real)**:Actual shipping days -- Días reales de envío del producto adquirido
# - **Days for shipment (scheduled)**:Days of scheduled delivery--  Días de entrega programada del producto adquirido

# %%
column_names = [ 'type','customer_city','customer_country','customer_state','latitude', 'longitude','customer_street', 
 'customer_zipcode','customer_id','customer_segment','market', 'order_city','order_country', 'order_region','order_state',
 'order_customer_id','department_id','department_name','order_id','order_item_id','order_item_quantity','order_item_cardprod_id','order_item_discount',
 'order_item_discount_rate','order_item_product_price','order_item_profit_ratio','benefit_per_order','order_profit_per_order',
 'order_item_total','product_price','sales_per_customer','sales','category_id','category_name', 
 'product_card_id','product_category_id','product_name', 'order_status','order_date_(dateorders)',
 'shipping_date_(dateorders)','shipping_mode','days_for_shipping_(real)','days_for_shipment_(scheduled)','delivery_status',
 'late_delivery_risk']
df1 = Data.reindex(columns=column_names)

# %%
df1.head(2)
# Out:
#        type customer_city customer_country customer_state   latitude  \
# 0     DEBIT        Caguas      Puerto Rico             PR  18.251453
# 1  TRANSFER        Caguas      Puerto Rico             PR  18.279451
#
#    longitude           customer_street  customer_zipcode  customer_id  \
# 0 -66.037056  5365 Noble Nectar Island               725        20755
# 1 -66.037064          2679 Rustic Loop               725        19492
#
#   customer_segment        market order_city order_country    order_region  \
# 0         Consumer  Pacific Asia     Bekasi     Indonesia  Southeast Asia
# 1         Consumer  Pacific Asia    Bikaner         India      South Asia
#
#        order_state  order_customer_id  department_id department_name  \
# 0  Java Occidental              20755              2         Fitness
# 1         Rajastán              19492              2         Fitness
#
#    order_id  order_item_id  order_item_quantity  order_item_cardprod_id  \
# 0     77202         180517                    1                    1360
# 1     75939         179254                    1                    1360
#
#    order_item_discount  order_item_discount_rate  order_item_product_price  \
# 0                13.11                      0.04                    327.75
# 1                16.39                      0.05                    327.75
#
#    order_item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0                     0.29              91.25                   91.25
# 1                    -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  sales_per_customer   sales  category_id  \
# 0            314.64         327.75              314.64  327.75           73
# 1            311.36         327.75              311.36  327.75           73
#
#     category_name  product_card_id  product_category_id  product_name  \
# 0  Sporting Goods             1360                   73  Smart watch
# 1  Sporting Goods             1360                   73  Smart watch
#
#   order_status order_date_(dateorders) shipping_date_(dateorders)  \
# 0     COMPLETE         1/31/2018 22:56             2/3/2018 22:56
# 1      PENDING         1/13/2018 12:27            1/18/2018 12:27
#
#     shipping_mode  days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 0  Standard Class                         3                              4
# 1  Standard Class                         5                              4
#
#     delivery_status  late_delivery_risk
# 0  Advance shipping                   0
# 1     Late delivery                   1

# %%
# df.customer_city.unique() CA--California city condado de Kern

# %%
df1.loc[df1['customer_state'] == '91732']
# Out:
#         type customer_city customer_country customer_state   latitude  \
# 82511  DEBIT            CA          EE. UU.          91732  34.071892
#
#         longitude customer_street  customer_zipcode  customer_id  \
# 82511 -118.013886        El Monte                 0        14046
#
#       customer_segment  market order_city order_country     order_region  \
# 82511         Consumer  Europe  Sheffield   Reino Unido  Northern Europe
#
#       order_state  order_customer_id  department_id department_name  order_id  \
# 82511  Inglaterra              14046              4         Apparel     70493
#
#        order_item_id  order_item_quantity  order_item_cardprod_id  \
# 82511         173808                    1                    1350
#
#        order_item_discount  order_item_discount_rate  \
# 82511                57.14                      0.16
#
#        order_item_product_price  order_item_profit_ratio  benefit_per_order  \
# 82511                     357.1                      0.2              59.99
#
#        order_profit_per_order  order_item_total  product_price  \
# 82511                   59.99            299.96          357.1
#
#        sales_per_customer  sales  category_id        category_name  \
# 82511              299.96  357.1           63  Children's Clothing
#
#        product_card_id  product_category_id        product_name order_status  \
# 82511             1350                   63  Children's heaters     COMPLETE
#
#       order_date_(dateorders) shipping_date_(dateorders)   shipping_mode  \
# 82511         10/26/2017 0:29            10/30/2017 0:29  Standard Class
#
#        days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 82511                         4                              4
#
#         delivery_status  late_delivery_risk
# 82511  Shipping on time                   0

# %%
df1['customer_state']=[i.replace(i,'CA') if i=='91732' or i=='95758' else i for i in df1['customer_state']]

# %%
df1.rename(columns = {'type':'transaction_type','customer_city':'store_city','customer_country':'store_country',
                     'customer_state':'store_state','latitude':'latitude_store','longitude':'longitude_store',
                     'customer_street':'store_street','customer_zipcode':'store_zipcode','market':'customer_market',
                     'order_city':'customer_city','order_item_cardprod_id':'rfid_order_id',
                     'sales_per_customer':'total_sales_per_customer','product_card_id':'product_id',
                     'order_date_(dateorders)':'order_date','shipping_date_(dateorders)':'delivery_date',
    'days_for_shipping_(real)':'real_shipping_days','days_for_shipment_(scheduled)':'scheduled_shipping_days',
                    'order_region':'customer_region','order_item_discount':'item_discount',
                      'order_item_discount_rate':'item_discount_rate',
                    'order_item_id':'item_id','order_item_profit_ratio':'item_profit_ratio',
                    'order_item_quantity':'item_quantity',}, inplace = True)

# %%
df1.head(2)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
#
#   customer_segment customer_market customer_city order_country  \
# 0         Consumer    Pacific Asia        Bekasi     Indonesia
# 1         Consumer    Pacific Asia       Bikaner         India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status       order_date    delivery_date   shipping_mode  \
# 0     COMPLETE  1/31/2018 22:56   2/3/2018 22:56  Standard Class
# 1      PENDING  1/13/2018 12:27  1/18/2018 12:27  Standard Class
#
#    real_shipping_days  scheduled_shipping_days   delivery_status  \
# 0                   3                        4  Advance shipping
# 1                   5                        4     Late delivery
#
#    late_delivery_risk
# 0                   0
# 1                   1

# %%
df1.rename(columns = {'order_country':'customer_country'}, inplace = True)

# %%
df1.head(2)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
#
#   customer_segment customer_market customer_city customer_country  \
# 0         Consumer    Pacific Asia        Bekasi        Indonesia
# 1         Consumer    Pacific Asia       Bikaner            India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status       order_date    delivery_date   shipping_mode  \
# 0     COMPLETE  1/31/2018 22:56   2/3/2018 22:56  Standard Class
# 1      PENDING  1/13/2018 12:27  1/18/2018 12:27  Standard Class
#
#    real_shipping_days  scheduled_shipping_days   delivery_status  \
# 0                   3                        4  Advance shipping
# 1                   5                        4     Late delivery
#
#    late_delivery_risk
# 0                   0
# 1                   1

# %%
df1.late_delivery_risk.value_counts()
# Out:
# 1    98977
# 0    81542
# Name: late_delivery_risk, dtype: int64

# %%
df1['order_date']=pd.to_datetime(df1['order_date'])      #convertimos a formato datetime para sacar año y mes
df1['delivery_date']=pd.to_datetime(df1['delivery_date'])

# %%
df1['order_year'] = df1['order_date'].dt.year
df1['order_month'] = df1['order_date'].dt.month

# %%
df1.head(2)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
#
#   customer_segment customer_market customer_city customer_country  \
# 0         Consumer    Pacific Asia        Bekasi        Indonesia
# 1         Consumer    Pacific Asia       Bikaner            India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status          order_date       delivery_date   shipping_mode  \
# 0     COMPLETE 2018-01-31 22:56:00 2018-02-03 22:56:00  Standard Class
# 1      PENDING 2018-01-13 12:27:00 2018-01-18 12:27:00  Standard Class
#
#    real_shipping_days  scheduled_shipping_days   delivery_status  \
# 0                   3                        4  Advance shipping
# 1                   5                        4     Late delivery
#
#    late_delivery_risk  order_year  order_month
# 0                   0        2018            1
# 1                   1        2018            1

# %%
df=df1.copy()

# %% [markdown]
# sum((df.month_orderdate == df.month_shippingdate) == False)==20957

# %% [markdown]
# sum((df.year_orderdate == df.year_shippingdate) == False)==1490

# %%
df['order_date']=df['order_date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))
df['delivery_date']=df['delivery_date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
df.head(3)
# Out:
#   transaction_type store_city store_country store_state  latitude_store  \
# 0            DEBIT     Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER     Caguas   Puerto Rico          PR       18.279451
# 2             CASH   San Jose       EE. UU.          CA       37.292233
#
#    longitude_store              store_street  store_zipcode  customer_id  \
# 0       -66.037056  5365 Noble Nectar Island            725        20755
# 1       -66.037064          2679 Rustic Loop            725        19492
# 2      -121.881279      8510 Round Bear Gate          95125        19491
#
#   customer_segment customer_market customer_city customer_country  \
# 0         Consumer    Pacific Asia        Bekasi        Indonesia
# 1         Consumer    Pacific Asia       Bikaner            India
# 2         Consumer    Pacific Asia       Bikaner            India
#
#   customer_region      order_state  order_customer_id  department_id  \
# 0  Southeast Asia  Java Occidental              20755              2
# 1      South Asia         Rajastán              19492              2
# 2      South Asia         Rajastán              19491              2
#
#   department_name  order_id  item_id  item_quantity  rfid_order_id  \
# 0         Fitness     77202   180517              1           1360
# 1         Fitness     75939   179254              1           1360
# 2         Fitness     75938   179253              1           1360
#
#    item_discount  item_discount_rate  order_item_product_price  \
# 0          13.11                0.04                    327.75
# 1          16.39                0.05                    327.75
# 2          18.03                0.06                    327.75
#
#    item_profit_ratio  benefit_per_order  order_profit_per_order  \
# 0               0.29              91.25                   91.25
# 1              -0.80            -249.09                 -249.09
# 2              -0.80            -247.78                 -247.78
#
#    order_item_total  product_price  total_sales_per_customer   sales  \
# 0            314.64         327.75                    314.64  327.75
# 1            311.36         327.75                    311.36  327.75
# 2            309.72         327.75                    309.72  327.75
#
#    category_id   category_name  product_id  product_category_id  product_name  \
# 0           73  Sporting Goods        1360                   73  Smart watch
# 1           73  Sporting Goods        1360                   73  Smart watch
# 2           73  Sporting Goods        1360                   73  Smart watch
#
#   order_status  order_date delivery_date   shipping_mode  real_shipping_days  \
# 0     COMPLETE  31/01/2018    03/02/2018  Standard Class                   3
# 1      PENDING  13/01/2018    18/01/2018  Standard Class                   5
# 2       CLOSED  13/01/2018    17/01/2018  Standard Class                   4
#
#    scheduled_shipping_days   delivery_status  late_delivery_risk  order_year  \
# 0                        4  Advance shipping                   0        2018
# 1                        4     Late delivery                   1        2018
# 2                        4  Shipping on time                   0        2018
#
#    order_month
# 0            1
# 1            1
# 2            1

# %%
#sum((df.order_item_total == df.total_sales_per_customer) == False)==0  #borramos la columna al ser igual que la otra

# %%
#sum((df.order_profit_per_order == df.benefit_per_order) == False)==0   #borramos la columna al ser igual que la otra

# %%
#sum((df.order_item_product_price == df.product_price) == False)==0     #borramos la columna al ser igual que la otra

# %%
df=df.drop(columns=['order_state','customer_market','order_item_total','order_profit_per_order',
                   'order_item_product_price','store_street','store_zipcode','rfid_order_id',
                   'department_id','category_id','product_category_id','order_customer_id','product_id'])

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount  item_discount_rate  item_profit_ratio  \
# 0              1          13.11                0.04               0.29
# 1              1          16.39                0.05              -0.80
# 2              1          18.03                0.06              -0.80
# 3              1          22.94                0.07               0.08
# 4              1          29.50                0.09               0.45
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
def country(x): 
    if x=='Japón':
        return 'Japan'
    elif x=='Corea del Sur':
        return 'South Korea'
    elif x=='Turquía':
        return 'Turkey'
    elif x=='Estados Unidos':
        return 'United States'
    elif x=='República Democrática del Congo':
        return 'DR Congo'
    elif x=='República del Congo':
        return 'DR Congo'
    elif x=='Marruecos':
        return 'Morocco'
    elif x=='Alemania':
        return 'Germany'
    elif x== 'Francia':
        return 'France'
    elif x=='Países Bajos':
        return 'Netherlands'
    elif x== 'Reino Unido':
        return 'United Kingdom'
    elif x=='Panamá' :
        return 'Panama'
    elif x=='República Dominicana':
        return 'Dominican Republic'
    elif x== 'Brasil':
        return 'Brazil'
    elif x=='México' :
        return 'Mexico'
    elif x== 'Perú':
        return 'Peru'
    elif x== 'Sudán':
        return 'Sudan'
    elif x== 'Costa de Marfil':
        return 'Ivory Coast'
    elif x== 'Libia':
        return 'Libya'
    elif x== 'Egipto':
        return 'Egypt'
    elif x== 'Italia':
        return 'Italy'
    elif x== 'España':
        return 'Spain'
    elif x== 'Suecia':
        return 'Sweden'
    elif x== 'Níger':
        return 'Niger'
    elif x== 'SudAfrica':
        return 'South Africa'
    elif x== 'Ruanda':
        return 'Rwanda'
    elif x== 'Nueva Zelanda':
        return 'New Zeland'
    elif x== 'Bangladés':
        return 'Bangladesh'
    elif x=='Trinidad y Tobago':
        return 'Trinidad and Tobago'
    elif x=='Tailandia':
        return 'Thailand'
    elif x=='Arabia Saudí':
        return 'Saudi Arabia'
    elif x=='Irán':
        return 'Iran'
    elif x=='Myanmar (Birmania)':
        return 'Myanmar'
    elif x=='Uzbekistán':
        return 'Uzbekistan'
    elif x=='Benín':
        return 'Benin'
    elif x=='Camerún':
        return 'Camerun'
    elif x=='Ucrania':
        return 'Ukraine'
    elif x=='Polonia':
        return 'Poland'
    elif x=='Rumania':
        return 'Romania'
    elif x=='Afganistán':
        return 'Afghanistan'
    elif x=='Pakistán':
        return 'Pakistan'
    elif x=='Malasia':
        return 'Malaysia'
    elif x=='Finlandia':
        return 'Finland'
    elif x=='Rusia':
        return 'Russia'
    elif x=='Irlanda':
        return 'Ireland'
    elif x=='Noruega':
        return 'Norway'
    elif x=='Eslovaquia':
        return 'Slovakia'
    elif x=='Bélgica':
        return 'Belgium'
    elif x=='Etiopía':
        return 'Ethiopia'
    elif x=='Lituania':
        return 'Lithuania'
    elif x=='Kirguistán':
        return 'Kyrgyzstan'
    elif x=='Lesoto':
        return 'Lesotho'
    elif x=='Emiratos Árabes Unidos':
        return 'United Arab Emirates'
    elif x=='Suiza':
        return 'Switzerland'
    elif x=='Hungría':
        return 'Hungary'
    elif x=='Dinamarca':
        return 'Denmark'
    elif x=='Haití':
        return 'Haiti'
    elif x=='Bielorrusia':
        return 'Belarus'
    elif x=='Croacia':
        return 'Croatia'
    elif x=='Baréin':
        return 'Bahrain'
    elif x=='Zimbabue':
        return 'Zimbabwe'
    elif x=='República Checa':
        return 'Czech Republic'
    elif x=='Tayikistán':
        return 'Tajikistan'
    elif x=='Papúa Nueva Guinea':
        return 'Papua New Guinea'
    elif x=='Azerbaiyán':
        return 'Azerbaijan'
    elif x=='Turkmenistán':
        return 'Turkmenistan'
    elif x=='Jordania':
        return 'Jordan'
    elif x=='Martinica':
        return 'Martinique'
    elif x=='Moldavia':
        return 'Moldova'
    elif x=='Bosnia y Herzegovina':
        return 'Bosnia and Herzegovina'
    elif x=='Omán':
        return 'Oman'
    elif x=='Túnez':
        return 'Tunisia'
    elif x=='Sierra Leona':
        return 'Sierra Leone'
    elif x=='Yibuti':
        return 'Djibouti'
    elif x=='Gabón':
        return 'Gabon'
    elif x=='Sudán del Sur':
        return 'Sudan'
    elif x=='Luxemburgo':
        return 'Luxembourg'
    elif x=='Mauritania':
        return 'Mauritania'
    elif x=='Grecia':
        return 'Greece'
    elif x=='Suazilandia':
        return 'Swaziland'
    elif x=='Guayana Francesa':
        return 'French Polynesia'
    elif x=='República Centroafricana':
        return 'Central African Republic'
    elif x=='Taiwán':
        return 'Taiwan'
    elif x=='Líbano':
        return 'Libano'
    elif x=='Chipre':
        return  'Cyprus'
    elif x=='Surinam':
        return 'Suriname'
    elif x=='Belice':
        return 'Belize'
    elif x=='República de Gambia':
        return 'Gambia'
    elif x=='Sáhara Occidental':
        return 'Western Sahara'
    elif x=='Botsuana':
        return 'Botswana'
    elif x=='Guinea Ecuatorial':
        return 'Guinea'
    elif x=='Bután':
        return 'Butan'
    elif x=='Filipinas':
        return 'Philippines'
    else:
        return x

# %%
df['customer_country']=df['customer_country'].apply(country)

# %%
df['item_discount_rate']=(df['item_discount_rate']*100).round(2).astype(str) +'%'
df['item_profit_ratio']=(df['item_profit_ratio']*100).round(2).astype(str) +'%'

# %%
df.shape
# Out:
# (180519, 34)

# %%
df['customer_country'] = df['customer_country'].astype(str)

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount item_discount_rate item_profit_ratio  \
# 0              1          13.11               4.0%             29.0%
# 1              1          16.39               5.0%            -80.0%
# 2              1          18.03               6.0%            -80.0%
# 3              1          22.94               7.0%              8.0%
# 4              1          29.50               9.0%             45.0%
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
df.store_city.value_counts()
# Out:
# Caguas         66770
# Chicago         3885
# Los Angeles     3417
# Brooklyn        3412
# New York        1816
#                ...
# Bartlett          25
# Malden            22
# Ponce             22
# Freehold          13
# CA                 3
# Name: store_city, Length: 563, dtype: int64

# %%
df.customer_city.value_counts()
# Out:
# Santo Domingo    2211
# New York City    2202
# Los Angeles      1845
# Tegucigalpa      1783
# Managua          1682
#                  ...
# Libourne            1
# Bergerac            1
# Juliaca             1
# Takasaki            1
# Pernik              1
# Name: customer_city, Length: 3597, dtype: int64

# %%
pd.set_option('display.max_rows', None)
#df.customer_country.value_counts()  pendiente de traducir

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount item_discount_rate item_profit_ratio  \
# 0              1          13.11               4.0%             29.0%
# 1              1          16.39               5.0%            -80.0%
# 2              1          18.03               6.0%            -80.0%
# 3              1          22.94               7.0%              8.0%
# 4              1          29.50               9.0%             45.0%
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
#apertura nueva tienda, precio producto/pais, tipos de cliente/mkt , ventas epocas del año (pedidos cancelados), xq late delivery

# %% [markdown]
# - product_price = total_sales_per_customer + item_discount / total_sales_per_customer+(item_discount_rate*prod.price)
# - benefit_per_order= item_profit_ratio * total_sales_per_customer
# - ###
#
# - **item_discount=item_discount_rate**= Descuento s/sales
# - **Sales**= product price * item_qty -- Benefecio
#
# - **item_profit_ratio**=benefit_per_order = Beneficio s/sales_per_customer
# - **Product_price**:  precio de venta
# - **sales_per_customer**: qty * product_price -discount_rate
#
# - Sales es el precio de venta sin quitar el descuento, las ganancias reales son del total_sales_per_customer

# %%
def usa(x):
    if x=='EE.UU':
        return 'United States'
    else:
        return x

# %%
df['store_country']=df['store_country'].apply(usa)

# %%
df.to_csv('Final_3.csv', index=False)

# %%
df.head()
# Out:
#   transaction_type   store_city store_country store_state  latitude_store  \
# 0            DEBIT       Caguas   Puerto Rico          PR       18.251453
# 1         TRANSFER       Caguas   Puerto Rico          PR       18.279451
# 2             CASH     San Jose       EE. UU.          CA       37.292233
# 3            DEBIT  Los Angeles       EE. UU.          CA       34.125946
# 4          PAYMENT       Caguas   Puerto Rico          PR       18.253769
#
#    longitude_store  customer_id customer_segment customer_city  \
# 0       -66.037056        20755         Consumer        Bekasi
# 1       -66.037064        19492         Consumer       Bikaner
# 2      -121.881279        19491         Consumer       Bikaner
# 3      -118.291016        19490      Home Office    Townsville
# 4       -66.037048        19489        Corporate    Townsville
#
#   customer_country customer_region department_name  order_id  item_id  \
# 0        Indonesia  Southeast Asia         Fitness     77202   180517
# 1            India      South Asia         Fitness     75939   179254
# 2            India      South Asia         Fitness     75938   179253
# 3        Australia         Oceania         Fitness     75937   179252
# 4        Australia         Oceania         Fitness     75936   179251
#
#    item_quantity  item_discount item_discount_rate item_profit_ratio  \
# 0              1          13.11               4.0%             29.0%
# 1              1          16.39               5.0%            -80.0%
# 2              1          18.03               6.0%            -80.0%
# 3              1          22.94               7.0%              8.0%
# 4              1          29.50               9.0%             45.0%
#
#    benefit_per_order  product_price  total_sales_per_customer   sales  \
# 0              91.25         327.75                    314.64  327.75
# 1            -249.09         327.75                    311.36  327.75
# 2            -247.78         327.75                    309.72  327.75
# 3              22.86         327.75                    304.81  327.75
# 4             134.21         327.75                    298.25  327.75
#
#     category_name  product_name     order_status  order_date delivery_date  \
# 0  Sporting Goods  Smart watch          COMPLETE  31/01/2018    03/02/2018
# 1  Sporting Goods  Smart watch           PENDING  13/01/2018    18/01/2018
# 2  Sporting Goods  Smart watch            CLOSED  13/01/2018    17/01/2018
# 3  Sporting Goods  Smart watch          COMPLETE  13/01/2018    16/01/2018
# 4  Sporting Goods  Smart watch   PENDING_PAYMENT  13/01/2018    15/01/2018
#
#     shipping_mode  real_shipping_days  scheduled_shipping_days  \
# 0  Standard Class                   3                        4
# 1  Standard Class                   5                        4
# 2  Standard Class                   4                        4
# 3  Standard Class                   3                        4
# 4  Standard Class                   2                        4
#
#     delivery_status  late_delivery_risk  order_year  order_month
# 0  Advance shipping                   0        2018            1
# 1     Late delivery                   1        2018            1
# 2  Shipping on time                   0        2018            1
# 3  Advance shipping                   0        2018            1
# 4  Advance shipping                   0        2018            1

# %%
df.shape
# Out:
# (180519, 34)

# %% [markdown]
# DATASET 2

# %%
df2=pd.read_csv('../DATA/DataCo/tokenized_access_logs.csv')

# %%
df2.columns=[e.lower().replace(' ', '_').strip() for e in df2.columns]
df2.head(2)
# Out:
#                                    product             category  \
# 0  adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1    The North Face Women's Recon Backpack   hunting & shooting
#
#             date month  hour department            ip  \
# 0  9/1/2017 6:00   Sep     6   fitness   37.97.182.65
# 1  9/1/2017 6:00   Sep     6  fan shop   206.56.112.1
#
#                                                  url
# 0  /department/fitness/category/baseball%20&%20so...
# 1  /department/fan%20shop/category/hunting%20&%20...

# %%
df2.shape
# Out:
# (469977, 8)

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2['year'] = df2['date'].dt.year
df2['month_'] = df2['date'].dt.month

# %%
df2=df2.drop(columns=['month','hour','url'])

# %%
df2.head(2)
# Out:
#                                    product             category  \
# 0  adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1    The North Face Women's Recon Backpack   hunting & shooting
#
#                  date department            ip  year  month_
# 0 2017-09-01 06:00:00   fitness   37.97.182.65  2017       9
# 1 2017-09-01 06:00:00  fan shop   206.56.112.1  2017       9

# %%
Datas=df2.copy()

# %%
Datas['date']=Datas['date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
Datas.head()
# Out:
#                                       product             category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#          date department              ip  year  month_
# 0  01/09/2017   fitness     37.97.182.65  2017       9
# 1  01/09/2017  fan shop     206.56.112.1  2017       9
# 2  01/09/2017   apparel    215.143.180.0  2017       9
# 3  01/09/2017  footwear     206.56.112.1  2017       9
# 4  01/09/2017  fan shop   136.108.56.242  2017       9

# %%
Datas.year.value_counts()
# Out:
# 2017    386396
# 2018     83581
# Name: year, dtype: int64

# %%
Datas.to_csv('Token2.csv', index=False)
